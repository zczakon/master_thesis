# %%
import itertools
import numpy as np
import re
from fractions import Fraction

# %%
dic17 = {('x1','x2'): {'x7':1}, ('x3','x4'): {'x7':1}, ('x5','x6'): {'x7':1}}
L17.<x1,x2,x3,x4,x5,x6,x7> = LieAlgebra(QQ, dic17)

dic157 = {('x1','x2'): {'x3':1}, ('x1','x3'): {'x7':1}, ('x2','x4'): {'x7':1}, ('x5','x6'): {'x7':1}}
L157.<x1,x2,x3,x4,x5,x6,x7> = LieAlgebra(QQ, dic157)

dic147A = {('x1','x2'): {'x4':1}, ('x1','x3'): {'x5':1}, ('x1','x6'): {'x7':1}, ('x2','x5'): {'x7':1},  
           ('x3','x4'): {'x7':1}}
L147A.<x1,x2,x3,x4,x5,x6,x7> = LieAlgebra(QQ, dic147A)

dic147A1 = {('x1','x2'): {'x4':1}, ('x1','x3'): {'x5':1}, ('x1','x6'): {'x7':1}, ('x2','x4'): {'x7':1},  
           ('x3','x5'): {'x7':1}}
L147A1.<x1,x2,x3,x4,x5,x6,x7> = LieAlgebra(QQ, dic147A1)

dic147B = {('x1','x2'): {'x4':1}, ('x1','x3'): {'x5':1}, ('x1','x4'): {'x7':1}, ('x2','x6'): {'x7':1},  
           ('x3','x5'): {'x7':1}}
L147B.<x1,x2,x3,x4,x5,x6,x7> = LieAlgebra(QQ, dic147B)

dic147D = {('x1','x2'): {'x4':1}, ('x1','x3'): {'x6':-1}, ('x1','x5'): {'x7':1}, ('x1','x6'): {'x7':1},  
           ('x2','x3'): {'x5':1}, ('x2','x6'): {'x7':1}, ('x3','x4'): {'x7':-2}}
L147D.<x1,x2,x3,x4,x5,x6,x7> = LieAlgebra(QQ, dic147D)

def L147E(c):
    pass


def L147E1(c):
    pass

dic1457B = {('x1','x2'): {'x3':1}, ('x1','x3'): {'x4':1}, ('x1','x4'): {'x7':1}, ('x2','x3'): {'x7':1},  
           ('x5','x6'): {'x7':1}}
L1457B.<x1,x2,x3,x4,x5,x6,x7> = LieAlgebra(QQ, dic1457B)

dic137B = {('x1','x2'): {'x5':1}, ('x1','x5'): {'x7':1}, ('x2','x4'): {'x7':1}, ('x3','x4'): {'x6':1},  
           ('x3','x6'): {'x7':1}}
L137B.<x1,x2,x3,x4,x5,x6,x7> = LieAlgebra(QQ, dic137B)

dic137B1 = {('x1','x3'): {'x5':1}, ('x1','x4'): {'x6':1}, ('x1','x5'): {'x7':1}, ('x2','x3'): {'x6':-1},  
           ('x2','x4'): {'x5':1}, ('x2','x6'): {'x7':1}, ('x3','x4'): {'x7':1}}
L137B1.<x1,x2,x3,x4,x5,x6,x7> = LieAlgebra(QQ, dic137B1)

dic137D = {('x1','x2'): {'x5':1}, ('x1','x4'): {'x6':1}, ('x1','x6'): {'x7':1}, ('x2','x3'): {'x6':1},  
           ('x2','x4'): {'x7':1}, ('x3','x5'): {'x7':-1}}
L137D.<x1,x2,x3,x4,x5,x6,x7> = LieAlgebra(QQ, dic137D)

dic1357A = {('x1','x2'): {'x4':1}, ('x1','x4'): {'x5':1}, ('x1','x5'): {'x7':1}, ('x2','x3'): {'x5':1},  
           ('x2','x6'): {'x7':1}, ('x3','x4'): {'x7':-1}}
L1357A.<x1,x2,x3,x4,x5,x6,x7> = LieAlgebra(QQ, dic1357A)

dic1357C = {('x1','x2'): {'x4':1}, ('x1','x4'): {'x5':1}, ('x1','x5'): {'x7':1}, ('x2','x3'): {'x5':1},  
           ('x2','x4'): {'x7':1}, ('x3','x4'): {'x7':-1}, ('x3','x6'): {'x7':1}}
L1357C.<x1,x2,x3,x4,x5,x6,x7> = LieAlgebra(QQ, dic1357C)

dic1357D = {('x1','x2'): {'x3':1}, ('x2','x3'): {'x5':1}, ('x2','x4'): {'x6':1}, ('x1','x6'): {'x7':1},  
           ('x2','x5'): {'x7':1}, ('x3','x4'): {'x7':1}}
L1357D.<x1,x2,x3,x4,x5,x6,x7> = LieAlgebra(QQ, dic1357D)

dic1357F = {('x1','x2'): {'x3':1}, ('x2','x3'): {'x5':1}, ('x2','x4'): {'x6':1}, ('x1','x3'): {'x7':1},  
           ('x2','x5'): {'x7':1}, ('x4','x6'): {'x7':-1}}
L1357F.<x1,x2,x3,x4,x5,x6,x7> = LieAlgebra(QQ, dic1357F)

dic1357F1 = {('x1','x2'): {'x3':1}, ('x2','x3'): {'x5':1}, ('x2','x4'): {'x6':1}, ('x1','x3'): {'x7':1},  
           ('x2','x5'): {'x7':1}, ('x4','x6'): {'x7':1}}
L1357F1.<x1,x2,x3,x4,x5,x6,x7> = LieAlgebra(QQ, dic1357F1)

dic1357H = {('x1','x2'): {'x3':1}, ('x1','x4'): {'x6':1}, ('x1','x6'): {'x7':1}, ('x2','x3'): {'x5':1},  
           ('x2','x5'): {'x7':1}, ('x2','x6'): {'x7':1}, ('x3','x4'): {'x7':-1}}
L1357H.<x1,x2,x3,x4,x5,x6,x7> = LieAlgebra(QQ, dic1357H)

dic1357J = {('x1','x2'): {'x3':1}, ('x1','x3'): {'x7':1}, ('x1','x4'): {'x6':1}, ('x2','x3'): {'x5':1},  
           ('x2','x5'): {'x7':1}, ('x4','x6'): {'x7':1}}
L1357J.<x1,x2,x3,x4,x5,x6,x7> = LieAlgebra(QQ, dic1357J)

dic1357L = {('x1','x2'): {'x3':1}, ('x1','x3'): {'x5':1}, ('x1','x4'): {'x6':1}, ('x1','x5'): {'x7':1},  
           ('x2','x3'): {'x7':1}, ('x2','x4'): {'x5':1}, ('x2','x6'): {'x7':1/2}, ('x3','x4'): {'x7':1/2}}
L1357L.<x1,x2,x3,x4,x5,x6,x7> = LieAlgebra(QQ, dic1357L)

def L1357M(c):
    pass

def L1357N(c):
    pass

dic1357P = {('x1','x2'): {'x3':1}, ('x1','x3'): {'x5':1}, ('x1','x5'): {'x7':1}, ('x2','x3'): {'x6':1},  
           ('x2','x4'): {'x5':1}, ('x2','x6'): {'x7':1}, ('x3','x4'): {'x7':1}}
L1357P.<x1,x2,x3,x4,x5,x6,x7> = LieAlgebra(QQ, dic1357P)

dic1357P1 = {('x1','x2'): {'x3':1}, ('x1','x3'): {'x5':1}, ('x1','x5'): {'x7':1}, ('x2','x3'): {'x6':1},  
           ('x2','x4'): {'x5':1}, ('x2','x6'): {'x7':-1}, ('x3','x4'): {'x7':1}}
L1357P1.<x1,x2,x3,x4,x5,x6,x7> = LieAlgebra(QQ, dic1357P1)

def L1357QRS1(c):
    pass

dic1357R = {('x1','x2'): {'x3':1}, ('x1','x3'): {'x5':1}, ('x1','x6'): {'x7':1}, ('x2','x3'): {'x6':1},  
           ('x2','x4'): {'x6':1}, ('x2','x5'): {'x7':1}, ('x3','x4'): {'x7':1}}
L1357R.<x1,x2,x3,x4,x5,x6,x7> = LieAlgebra(QQ, dic1357R)

def L1357S(c):
    pass

dic13457C = {('x1','x2'): {'x3':1}, ('x1','x3'): {'x4':1}, ('x1','x4'): {'x5':1}, ('x1','x6'): {'x7':1},  
           ('x2','x5'): {'x7':1}, ('x3','x4'): {'x7':-1}}
L13457C.<x1,x2,x3,x4,x5,x6,x7> = LieAlgebra(QQ, dic13457C)

dic13457E = {('x1','x2'): {'x3':1}, ('x1','x3'): {'x4':1}, ('x1','x4'): {'x5':1}, ('x1','x6'): {'x7':1},  
           ('x2','x3'): {'x5':1}, ('x2','x5'): {'x7':1}, ('x3','x4'): {'x7':-1}}
L13457E.<x1,x2,x3,x4,x5,x6,x7> = LieAlgebra(QQ, dic13457E)

dic13457G = {('x1','x2'): {'x3':1}, ('x1','x3'): {'x4':1}, ('x1','x4'): {'x5':1}, ('x1','x6'): {'x7':1},  
           ('x2','x3'): {'x6':1}, ('x2','x4'): {'x7':1}, ('x2','x5'): {'x7':1}, ('x3','x4'): {'x7':-1}}
L13457G.<x1,x2,x3,x4,x5,x6,x7> = LieAlgebra(QQ, dic13457G)

dic13457I = {('x1','x2'): {'x3':1}, ('x1','x3'): {'x4':1}, ('x1','x4'): {'x5':1}, ('x1','x5'): {'x7':1},  
           ('x2','x3'): {'x6':1}, ('x2','x5'): {'x7':1}, ('x2','x6'): {'x7':1}, ('x3','x4'): {'x7':-1}}
L13457I.<x1,x2,x3,x4,x5,x6,x7> = LieAlgebra(QQ, dic13457I)

dic12457D = {('x1','x2'): {'x3':1}, ('x1','x3'): {'x4':1}, ('x2','x6'): {'x7':1}, ('x2','x5'): {'x6':1},  
           ('x1','x4'): {'x6':1}, ('x1','x5'): {'x7':1}, ('x3','x4'): {'x7':-1}}
L12457D.<x1,x2,x3,x4,x5,x6,x7> = LieAlgebra(QQ, dic12457D)

dic12457E = {('x1','x2'): {'x3':1}, ('x1','x3'): {'x4':1}, ('x1','x4'): {'x6':1}, ('x1','x6'): {'x7':1},  
           ('x2','x3'): {'x6':1}, ('x2','x4'): {'x7':1}, ('x2','x5'): {'x6':1}, ('x3','x5'): {'x7':1}}
L12457E.<x1,x2,x3,x4,x5,x6,x7> = LieAlgebra(QQ, dic12457E)

dic12457G = {('x1','x2'): {'x3':1}, ('x1','x3'): {'x4':1}, ('x1','x4'): {'x6':1}, ('x1','x5'): {'x7':1},  
           ('x2','x5'): {'x6':1}, ('x2','x6'): {'x7':1}, ('x2','x3'): {'x6':1}, ('x3','x4'): {'x7':-1}}
L12457G.<x1,x2,x3,x4,x5,x6,x7> = LieAlgebra(QQ, dic12457G)

dic12457I = {('x1','x2'): {'x3':1}, ('x1','x3'): {'x4':1}, ('x1','x5'): {'x6':1}, ('x1','x6'): {'x7':1},  
           ('x3','x4'): {'x7':1}, ('x2','x5'): {'x7':1}, ('x2','x3'): {'x5':1}, ('x2','x4'): {'x6':1}}
L12457I.<x1,x2,x3,x4,x5,x6,x7> = LieAlgebra(QQ, dic12457I)

dic12457J = {('x1','x2'): {'x3':1}, ('x1','x3'): {'x4':1}, ('x1','x5'): {'x6':1}, ('x1','x6'): {'x7':1},  
           ('x1','x4'): {'x7':1}, ('x2','x3'): {'x5':1}, ('x2','x4'): {'x6':1}, ('x2','x5'): {'x7':1}, 
             ('x3','x4'): {'x7':1}}
L12457J.<x1,x2,x3,x4,x5,x6,x7> = LieAlgebra(QQ, dic12457J)

dic12457J1 = {('x1','x2'): {'x3':1}, ('x1','x3'): {'x4':1}, ('x1','x5'): {'x6':1}, ('x1','x6'): {'x7':1},  
           ('x1','x4'): {'x7':1}, ('x2','x5'): {'x7':-1}, ('x2','x3'): {'x5':1}, ('x2','x4'): {'x6':1}, 
              ('x3','x4'): {'x7':1}}
L12457J1.<x1,x2,x3,x4,x5,x6,x7> = LieAlgebra(QQ, dic12457J1)

dic12457L = {('x1','x2'): {'x3':1}, ('x1','x3'): {'x4':1}, ('x1','x5'): {'x6':1}, ('x1','x6'): {'x7':1},  
           ('x3','x4'): {'x7':1}, ('x2','x6'): {'x7':1}, ('x2','x3'): {'x5':1}, ('x2','x4'): {'x6':1}, 
              ('x3','x5'): {'x7':-1}}
L12457L.<x1,x2,x3,x4,x5,x6,x7> = LieAlgebra(QQ, dic12457L)

def L12457N(c):
    pass

def L12457N2(c):
    pass

dic12357C = {('x1','x2'): {'x4':1}, ('x1','x4'): {'x5':1}, ('x1','x5'): {'x6':1}, ('x1','x6'): {'x7':1},  
           ('x2','x3'): {'x5':1}, ('x2','x4'): {'x7':1}, ('x3','x4'): {'x6':-1}, ('x3','x5'): {'x7':-1}}
L12357C.<x1,x2,x3,x4,x5,x6,x7> = LieAlgebra(QQ, dic12357C)

dic123457C = {('x1','x2'): {'x3':1}, ('x1','x3'): {'x4':1}, ('x1','x4'): {'x5':1}, ('x1','x5'): {'x6':1},  
           ('x1','x6'): {'x7':1}, ('x2','x5'): {'x7':1}, ('x3','x4'): {'x7':-1}}
L123457C.<x1,x2,x3,x4,x5,x6,x7> = LieAlgebra(QQ, dic123457C)

dic123457F = {('x1','x2'): {'x3':1}, ('x1','x3'): {'x4':1}, ('x1','x4'): {'x5':1}, ('x1','x5'): {'x6':1},  
           ('x1','x6'): {'x7':1}, ('x2','x3'): {'x6':1}, ('x2','x4'): {'x7':1}, ('x2','x5'): {'x7':1}, 
              ('x3','x4'): {'x7':-1}}
L123457F.<x1,x2,x3,x4,x5,x6,x7> = LieAlgebra(QQ, dic123457F)

def L123457I(c):
    pass

# %%
algebras_static=[L17, L157, L147A, L147A1, L147B, L147D, L1457B, L137B, L137B1, L137D, L1357A, L1357C, L1357D, L1357F, L1357F1, L1357H, L1357J, L1357L, L1357P, L1357P1, L1357R, L13457C, L13457E, L13457G, L13457I, L12457D, L12457E, L12457G, L12457I, L12457J, L12457J1, L12457L, L12357C, L123457C, L123457F]
dics=[dic17, dic157, dic147A, dic147A1, dic147B, dic147D, dic1457B, dic137B, dic137B1, dic137D, dic1357A, dic1357C, dic1357D, dic1357F, dic1357F1, dic1357H, dic1357J, dic1357L, dic1357P, dic1357P1, dic1357R, dic13457C, dic13457E, dic13457G, dic13457I, dic12457D, dic12457E, dic12457G, dic12457I, dic12457J, dic12457J1, dic12457L, dic12357C, dic123457C, dic123457F]
algebras_dics=[(algebras_static[i],dics[i]) for i in range(35)]

algebra_names=['L17', 'L157', 'L147A', 'L147A1', 'L147B', 'L147D', 'L1457B', 'L137B', 'L137B1', 'L137D', 'L1357A', 'L1357C', 'L1357D', 'L1357F', 'L1357F1', 'L1357H', 'L1357J', 'L1357L', 'L1357P', 'L1357P1', 'L1357R', 'L13457C', 'L13457E', 'L13457G', 'L13457I', 'L12457D', 'L12457E', 'L12457G', 'L12457I', 'L12457J', 'L12457J1', 'L12457L', 'L12357C', 'L123457C', 'L123457F']
dic_names = str(algebra_names).replace('L1','dic1').replace("'","").strip('][').split(', ')
names=[(algebra_names[i],dic_names[i]) for i in range(35)]

def get_algebra_name(L):
    name_algebra_dict=dict(zip(algebra_names,algebras_static))
    for name, algebra in name_algebra_dict.items():
        if algebra == L:
            return name

# %%
def ordered_forms(generators: iter, deg: int):
    if not 1 <= deg < len(generators):
        print('degree not allowed')
        return

    generators = list(itertools.combinations(generators, deg))
    unique = list(set(generators))
    return sorted(list(unique))


def extract_vector(element):  # of the form Chain(1:(0, 1, 0, 0))
    element = str(element)
    # vector=str((list(cochain.homology(generators=True).values())[1][1][1]))
    gen = element[9:len(element) - 2]
    gen = gen.replace(', ', '')
    gen = gen.replace('-', '')
    gen = gen.replace('1/2','1')
    gen = gen.replace('3/2','1')
    gen = gen.replace('1/3','1')
    gen = gen.replace('2/3','1')

    vector = [int(gen[i]) for i in range(len(gen))]
    return vector


# i have a list of tuples [(Vector space of dimension 1 over Rational Field, Chain(1:(1, 0, 0, 0))),
#                         (Vector space of dimension 1 over Rational Field, Chain(1:(0, 1, 0, 0))),
#                         (Vector space of dimension 1 over Rational Field, Chain(1:(0, 0, 0, 1)))]

def translate_to_forms(homology_gens: list, deg: int, generators: iter):
    """
    return list of lists which are wedge products of generating forms. list(x^y^z, y^z^w,...)
    """
    homology_gens = homology_gens[0]

    generating_forms = []
    for n in range(len(homology_gens)):
        # vector = extract part of a string
        vector = extract_vector(homology_gens[n][1])
        generating_forms.append([])
        for i in range(len(vector)):
            if vector[i] != 0:
                generating_forms[n].append(ordered_forms(generators, deg)[i])
    return generating_forms


def cohomology_deg(cohomology: dict, deg: int):
    return [cohomology[key] for key in cohomology.keys() if key == deg]

def generate_cohomology(lie_algebra, deg):
    generators = list(lie_algebra.gens())
    if deg == 0 or deg >= len(generators):
        print('degree not allowed')
        return
    cochain = lie_algebra.chevalley_eilenberg_complex(dual=True)
    cohomology = cochain.homology(generators=True)
    cohomologies = [cohomology_deg(cohomology, n) for n in range(len(cohomology.keys()))]
    list_of_generators= translate_to_forms(cohomologies[deg], deg=deg, generators=generators)
    generators_readable=[]
    for i in range(len(list_of_generators)):
        tuple = (list_of_generators[i][0])
        string = str(tuple).replace(', ', '^').replace('(', '').replace(')', '').replace(',', '')
#         if len(string) == 5:  # forms of deg 1
#             string = string.replace(',', '')
        generators_readable.append(string)
    return generators_readable


def display(list_of_generators: iter):
    for gen in list_of_generators:
        print('['+gen+']')
    pass

# %%
n=7
def is_isomorphism_possible(L):
    for p in range(1,4):
        if len(generate_cohomology(L,p))!= len(generate_cohomology(L,n-p)):
            print('Isomorphism not possible for degrees',p,',',n-p,'for algebra',str(algebras_static[L]))
    pass

for i in range(len(algebras_static)):
    try:
        is_isomorphism_possible(algebras_static[i])
    except ValueError:
        print('Found ValueError for algebra',str(names[i]))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-137-ea4c9d797b6e> in <module>
#       8 for i in range(len(algebras_static)):
#       9     try:
# ---> 10         is_isomorphism_possible(algebras_static[i])
#      11     except ValueError:
#      12         print('Found ValueError for algebra',str(names[i]))
#
# <ipython-input-137-ea4c9d797b6e> in is_isomorphism_possible(L)
#       2 def is_isomorphism_possible(L):
#       3     for p in range(Integer(1),Integer(4)):
# ----> 4         if len(generate_cohomology(L,p))!= len(generate_cohomology(L,n-p)):
#       5             print('Isomorphism not possible for degrees',p,',',n-p,'for algebra',str(algebras_static[L]))
#       6     pass
#
# <ipython-input-136-4fab9ff8e8a9> in generate_cohomology(lie_algebra, deg)
#      54         return
#      55     cochain = lie_algebra.chevalley_eilenberg_complex(dual=True)
# ---> 56     cohomology = cochain.homology(generators=True)
#      57     cohomologies = [cohomology_deg(cohomology, n) for n in range(len(cohomology.keys()))]
#      58     list_of_generators= translate_to_forms(cohomologies[deg], deg=deg, generators=generators)
#
# /opt/sagemath-9.2/local/lib/python3.7/site-packages/sage/homology/chain_complex.py in homology(self, deg, base_ring, generators, verbose, algorithm)
#    1303             answer = {}
#    1304             for deg in self.nonzero_degrees():
# -> 1305                 answer[deg] = self._homology_in_degree(deg, base_ring, verbose, generators, algorithm)
#    1306             return answer
#    1307         else:
#
# /opt/sagemath-9.2/local/lib/python3.7/site-packages/sage/homology/chain_complex.py in _homology_in_degree(self, deg, base_ring, verbose, generators, algorithm)
#    1349
#    1350         if generators:
# -> 1351             orders, gens = self._homology_generators_snf(d_in, d_out, d_out_rank)
#    1352             answer = [(HomologyGroup(1, base_ring, [order]), self({deg:gen}))
#    1353                       for order, gen in zip(orders, gens)]
#
# /opt/sagemath-9.2/local/lib/python3.7/site-packages/sage/homology/chain_complex.py in _homology_generators_snf(self, d_in, d_out, d_out_rank)
#    1404
#    1405         # Find the SNF of the induced matrix and appropriate generators
# -> 1406         (N, P, Q) = d_in_induced.smith_form()
#    1407         all_divs = [0]*N.nrows()
#    1408         non_triv = 0
#
# /opt/sagemath-9.2/local/lib/python3.7/site-packages/sage/matrix/matrix2.pyx in sage.matrix.matrix2.Matrix.smith_form (build/cythonized/sage/matrix/matrix2.c:94318)()
#   14459         mm = t.submatrix(1,1)
#   14460         if transformation:
# > 14461             dd, uu, vv = mm.smith_form(transformation=True)
#   14462         else:
#   14463             dd = mm.smith_form(transformation=False)
#
# /opt/sagemath-9.2/local/lib/python3.7/site-packages/sage/matrix/matrix2.pyx in sage.matrix.matrix2.Matrix.smith_form (build/cythonized/sage/matrix/matrix2.c:94318)()
#   14459         mm = t.submatrix(1,1)
#   14460         if transformation:
# > 14461             dd, uu, vv = mm.smith_form(transformation=True)
#   14462         else:
#   14463             dd = mm.smith_form(transformation=False)
#
# /opt/sagemath-9.2/local/lib/python3.7/site-packages/sage/matrix/matrix2.pyx in sage.matrix.matrix2.Matrix.smith_form (build/cythonized/sage/matrix/matrix2.c:94318)()
#   14459         mm = t.submatrix(1,1)
#   14460         if transformation:
# > 14461             dd, uu, vv = mm.smith_form(transformation=True)
#   14462         else:
#   14463             dd = mm.smith_form(transformation=False)
#
# /opt/sagemath-9.2/local/lib/python3.7/site-packages/sage/matrix/matrix2.pyx in sage.matrix.matrix2.Matrix.smith_form (build/cythonized/sage/matrix/matrix2.c:94318)()
#   14459         mm = t.submatrix(1,1)
#   14460         if transformation:
# > 14461             dd, uu, vv = mm.smith_form(transformation=True)
#   14462         else:
#   14463             dd = mm.smith_form(transformation=False)
#
# /opt/sagemath-9.2/local/lib/python3.7/site-packages/sage/matrix/matrix2.pyx in sage.matrix.matrix2.Matrix.smith_form (build/cythonized/sage/matrix/matrix2.c:94318)()
#   14459         mm = t.submatrix(1,1)
#   14460         if transformation:
# > 14461             dd, uu, vv = mm.smith_form(transformation=True)
#   14462         else:
#   14463             dd = mm.smith_form(transformation=False)
#
# /opt/sagemath-9.2/local/lib/python3.7/site-packages/sage/matrix/matrix2.pyx in sage.matrix.matrix2.Matrix.smith_form (build/cythonized/sage/matrix/matrix2.c:94218)()
#   14453
#   14454         # first clear the first row and column
# > 14455         u,t,v = _smith_onestep(self)
#   14456
#   14457         # now recurse: t now has a nonzero entry at 0,0 and zero entries in the rest
#
# /opt/sagemath-9.2/local/lib/python3.7/site-packages/sage/matrix/matrix2.pyx in sage.matrix.matrix2._smith_onestep (build/cythonized/sage/matrix/matrix2.c:113016)()
#   16695             raise ArithmeticError
#   16696
# > 16697     left_mat, a = _generic_clear_column(a)
#   16698     assert left_mat * m * right_mat == a
#   16699
#
# /opt/sagemath-9.2/local/lib/python3.7/site-packages/sage/matrix/matrix2.pyx in sage.matrix.matrix2._generic_clear_column (build/cythonized/sage/matrix/matrix2.c:112364)()
#   16652         a.add_multiple_of_row(i, 0, -s )
#   16653         left_mat.add_multiple_of_row(i, 0, -s)
# > 16654     if left_mat * m != a:
#   16655         raise ArithmeticError
#   16656
#
# /opt/sagemath-9.2/local/lib/python3.7/site-packages/sage/structure/element.pyx in sage.structure.element.Matrix.__mul__ (build/cythonized/sage/structure/element.c:23925)()
#    3813
#    3814         if BOTH_ARE_ELEMENT(cl):
# -> 3815             return coercion_model.bin_op(left, right, mul)
#    3816
#    3817         cdef long value
#
# /opt/sagemath-9.2/local/lib/python3.7/site-packages/sage/structure/coerce.pyx in sage.structure.coerce.CoercionModel.bin_op (build/cythonized/sage/structure/coerce.c:10181)()
#    1192         if action is not None:
#    1193             if (<Action>action)._is_left:
# -> 1194                 return (<Action>action)._act_(x, y)
#    1195             else:
#    1196                 return (<Action>action)._act_(y, x)
#
# /opt/sagemath-9.2/local/lib/python3.7/site-packages/sage/matrix/action.pyx in sage.matrix.action.MatrixMatrixAction._act_ (build/cythonized/sage/matrix/action.c:5061)()
#     265                 A = A.dense_matrix()
#     266         assert type(A) == type(B), (type(A), type(B))
# --> 267         prod = A._matrix_times_matrix_(B)
#     268         if A._subdivisions is not None or B._subdivisions is not None:
#     269             Asubs = A.subdivisions()
#
# /opt/sagemath-9.2/local/lib/python3.7/site-packages/sage/matrix/matrix_rational_dense.pyx in sage.matrix.matrix_rational_dense.Matrix_rational_dense._matrix_times_matrix_ (build/cythonized/sage/matrix/matrix_rational_dense.c:11698)()
#    1153             TypeError: unsupported operand parent(s) for *: 'Full MatrixSpace of 2 by 3 dense matrices over Rational Field' and 'Full MatrixSpace of 4 by 5 dense matrices over Rational Field'
#    1154         """
# -> 1155         return self._multiply_flint(right)
#    1156
#    1157     def _multiply_flint(self, Matrix_rational_dense right):
#
# /opt/sagemath-9.2/local/lib/python3.7/site-packages/sage/matrix/matrix_rational_dense.pyx in sage.matrix.matrix_rational_dense.Matrix_rational_dense._multiply_flint (build/cythonized/sage/matrix/matrix_rational_dense.c:11930)()
#    1176             parent = self.parent()
#    1177         else:
# -> 1178             parent = self.matrix_space(self._nrows, right._ncols)
#    1179
#    1180         cdef Matrix_rational_dense ans
#
# /opt/sagemath-9.2/local/lib/python3.7/site-packages/sage/matrix/matrix1.pyx in sage.matrix.matrix1.Matrix.matrix_space (build/cythonized/sage/matrix/matrix1.c:18880)()
#    2476             else:
#    2477                 implementation = None
# -> 2478             from sage.matrix.matrix_space import MatrixSpace
#    2479             return MatrixSpace(base_ring, nrows, ncols, sparse, implementation)
#    2480
#
# /usr/lib/python3.7/importlib/_bootstrap.py in _handle_fromlist(module, fromlist, import_, recursive)
#
# src/cysignals/signals.pyx in cysignals.signals.python_check_interrupt()
#
# KeyboardInterrupt:

# %%
U = Manifold(7, 'U')
X.<x1,x2,x3,x4,x5,x6,x7> = U.chart()
dic=dic17

def check_lefschetz_theorem(L,dic=dic):
    flag=0
    for p in range(0,3):
        domain=set(generate_cohomology(L,3-p))
        codomain=set(generate_cohomology(L,3+p+1))
        while '0' in domain:
            domain.remove('0')
        while '0' in codomain:
            codomain.remove('0')
#       for gen in domain:
#             if lefschetz(to_form(gen),p) not in codomain:
#                 print('The claim is not satisfied for generator '+'['+str(gen)+']'+' because image is not in codomain.')
        
        image=set([to_string(lefschetz(to_form(gen),p,dic)) for gen in domain])
        while '0' in image:
            image.remove('0')
        #duplicates cannot occur
        print('codomain',codomain)
        print('image',image)
        if len(image)!=len(codomain):
            print('The claim is not satisfied for p='+str(p)+' for '+get_algebra_name(L)+' because of duplicates.')
            flag=1
        else:
            print('The claim is satisfied for p='+str(p)+' for '+get_algebra_name(L)+' in terms of duplicates.')
    if flag==1:
        return False
    else:
        print('Succes for',get_algebra_name(L))
        return True

def check_lefschetz_theoremB(L,dic=dic):
    flag=0
    for p in range(1,3):
        domain=set([gen for gen in generate_cohomology(L,3-p) if 'x7' not in gen])
        codomain=set([gen for gen in generate_cohomology(L,3+p) if 'x7' not in gen])
        while '0' in domain:
            domain.remove('0')
        while '0' in codomain:
            codomain.remove('0')
#       for gen in domain:
#             if lefschetz(to_form(gen),p) not in codomain:
#                 print('The claim is not satisfied for generator '+'['+str(gen)+']'+' because image is not in codomain.')
        
        image=set([to_string(lefschetzB(to_form(gen),p,dic)) for gen in domain])
        while '0' in image:
            image.remove('0')
        #duplicates cannot occur
        print('codomain',codomain)
        print('image',image)
        if len(image)!=len(codomain):
            print('The claim is not satisfied for p='+str(p)+' for '+get_algebra_name(L)+' because of duplicates.')
            flag=1
        else:
            print('The claim is satisfied for p='+str(p)+' for '+get_algebra_name(L)+' in terms of duplicates.')
            
    if flag==1:
        return False
    else:
        print('Succes for',get_algebra_name(L))
        return True

def lefschetz(form, p, dic=dic):
    contact=U.diff_form(1,'n')
    contact[6]=1
    #print('d(contact) ',str(d(contact,dic).display()))
    return __wedge__(__wedge__(contact,pow(d(contact,dic),p)),proj(form,dic))
                        
def lefschetzB(form, p, dic=dic):
    contact=U.diff_form(1,'n')
    contact[6]=1
    #print('d(contact) ',str(d(contact,dic).display()))
    return __wedge__(pow(d(contact,dic),p),proj(form,dic))
    
def proj(form,dic=dic):
    if d(form,dic)==0 and d_star(form,dic)==0:
        return form
    else:
        return 0
    
def pow(form, p):
    result=form
    if p==0:
        return 1
    if p==1 or form == 0:
        return result
    for i in range(p-1):
        result= __wedge__(result,form)
    return result

# %%
def __to_form__(form_string):
    #works on basis
    if form_string=='0':
        return 0
    form_string=form_string.replace('^','')
    n=len(form_string)/2
    f=U.diff_form(n,'f')
    if n==1:
        i=int(form_string[1])-1
        f[i]=1
    if n>=2:
        vector=np.zeros(n)
        for i in range(n):
            vector[i]=int(form_string[i*2+1])-1
        vector=vector.astype(int)
        exec('f'+str(list(vector))+'=1')       
    return f

def simplify(form_string):
    return form_string.replace('^','').replace('/\\','').replace('d','')

def to_form(form_string):
    form_string=simplify(form_string)
    
    split = re.split(' [+-] | ', form_string)
    if len(split)==1:
        return __to_form__(split[0])
    else:
        result=0
        n=len(split[1].replace('^',''))/2
        for j in range(len(split)):
            if 'x' not in split[j] and '0' != split[j]:
                split[j] = float(Fraction(split[j]))
                result = result + float(split[j])*__to_form__(split[j+1])
                split[j+1]='0'
            elif '0'==split[j]:
                continue
            else:
                result = result + __to_form__(split[j])
            
        return result

def to_string(form):
    if form==0:
        return '0'
    
    form_string= str(form.display())
    form_string=simplify(form_string)
    split_form_string = form_string.split(' = ')
    try:
        return split_form_string[1]
    except:
        return split_form_string[0]

# %%
def d_on_basis(form_string, dic):
    #TODO the one with two gens in structure constants
    d=U.diff_form(2,'d')
    for structure_const in dic.values():
        if list(structure_const.keys())[0]==form_string:
            keys=[]
            for key, value in dic.items():
                if value == structure_const:
                    i=int(key[0][1])-1
                    j=int(key[1][1])-1
                    d[i,j]=list(structure_const.values())[0]
    try:
        trial=d.display()
        return d
    except ValueError:
        return 0

def is_constant(form_string):
    form_string=str(form_string)
    if 'x' in form_string:
        return False
    else:
        return True
    
def is_1_form(form_string):
    if form_string.count('x')==1:
        return True
    else:
        return False
    
def d_of_nform(form_string):
    if form_string==0:
        return 0
    form1_string=form_string[:2]
    form2_string=form_string[2:]
    return __wedge__(d(to_form(form1_string),dic),to_form(form2_string)) - __wedge__(to_form(form1_string),d(to_form(form2_string),dic))

    

def d(form, dic=dic):
    form_string=to_string(form)
    
    if form_string == '0':
        return 0 
    elif is_1_form(form_string):
        #TODO name this condition and perhaps whole fnc can be still simplified
        if len(form_string)==2:
            return d_on_basis(form_string, dic)
        else:
            split = re.split(' [+-] | ', form_string)
            result=float(split[0])*d_on_basis(split[1],dic)  
    else: 
        split = re.split(' [+-] | ', form_string)
        result=0
        #print('split',split)
        for i in range(len(split)):
            if split[i]==0:
                continue
            elif is_constant(split[i]):
                #print('split[i]',split[i])
                #print('split[i+1]',split[i+1])
                result += float(split[i])*d_of_nform(split[i+1])
                split[i+1]=0
            else:
                result+= d_of_nform(split[i]) #here is the error       
    try:
        trial=result.display()
        return result
    except AttributeError:
        return 0
            
def __wedge__(form1, form2):
    if form2 ==1:
        return form1
    elif form1==1:
        return form2
    elif form1 !=0 and form2 !=0:
        return form1.wedge(form2)
    else:
        return 0

# %% [markdown]
# Implementing the star operator for contact manifold:
# $$\phi:X^*(M) \to \Omega^*(M)$$
# $$\phi^{-1}:\Omega^*(M) \to X^*(M)$$
# $$\psi:X^*(M) \to \Omega^{2n-*}(M) $$
# $$\star :\Omega^*(M) \to X^*(M) \to \Omega^{2n-*}(M), \; \star \beta =\psi \circ \phi^{-1}(\beta)$$

# %%
def __phi__(v, dic=dic):
    contact=to_form('x7')
    deta=d(contact,dic)
    return v.interior_product(deta)

def create_phi_map_dict(dic=dic):
    #TODO fix the -1's
    phi_map={}
    for i in range(7):
        t=np.zeros(7)
        t[i]=1
        v=U.vector_field('v')
        v[:]=tuple(t)
        image=to_string(__phi__(v, dic))        
        if '-' in image:
            t[i]=-1*t[i]
            phi_map[tuple(t)]=image.replace('-','')
        else:
            phi_map[tuple(t)]=image 
    return phi_map

def invert_map(map_dictionary):
    return {v: k for k, v in map_dictionary.items()}

# %%
def split_to_1forms(base_form):
    base_form=to_string(base_form)
    return [base_form[2*i:(2*i+2)] for i in range(len(base_form)/2)]

def __phi_inv__(form_string, dic=dic):
    phi_map=create_phi_map_dict(dic)
    inv_phi_map = invert_map(phi_map)
    #TODO have to map 'x7' to sth.
    inv_phi_map['x7'] = inv_phi_map['0']
    inv_phi_map.pop('0', None)
    return inv_phi_map[form_string]

def phi_inv_base(form):
    #works on base forms
    split=split_to_1forms(form)
    return [__phi_inv__(one_form) for one_form in split]

def compute_volume_form(dic=dic):
    contact=to_form('x7')
    deta=d(contact,dic)
    return deta.wedge(deta).wedge(deta)

def to_vector_field(vf_tuple):
    v=U.vector_field('v')
    v[:]=vf_tuple
    return v

def psi_base(list_vf, dic=dic):
    #returns a form
    list_vf=list(map(to_vector_field, list_vf))
    volume_form=compute_volume_form(dic)
    result=list_vf[::-1][0].interior_product(volume_form)
    n=len(list_vf)
    if n==1:
        return result
    for i in range(1,len(list_vf)):
        result=list_vf[::-1][0].interior_product(result)
    return result

# %%
def star(form):
    #works for base nforms
    if form==0:
        return 0
    return psi_base(phi_inv_base(form))

def d_star(form, dic=dic):
    form_string=to_string(form)                  
    dim=len(form_string)/2
    return (-1)**dim*star(d(star(form),dic))

# %%
#TODO testing

# %%
not_okay=[]
for L,dic in algebras_dics:
    if check_lefschetz_theorem(L,dic)==False:
        not_okay.append(L)
len(not_okay)
# Out:
# codomain {'x1^x3^x4^x5', 'x1^x3^x4^x7', 'x2^x5^x6^x7', 'x1^x4^x5^x6', 'x1^x3^x6^x7', 'x2^x3^x5^x7', 'x1^x4^x6^x7', 'x1^x3^x5^x6', 'x1^x2^x4^x6', 'x1^x2^x4^x5', 'x3^x4^x5^x6', 'x1^x2^x3^x7', 'x1^x2^x5^x7', 'x1^x4^x5^x7'}
# image {'-x2x4x6x7', '-x1x4x5x7', '-x2x3x4x7', '-x2x3x6x7'}
# The claim is not satisfied for p=0 for L17 because of duplicates.
# codomain {'x1^x2^x3^x4^x5', 'x2^x3^x4^x5^x7', 'x1^x2^x3^x5^x6', 'x1^x2^x3^x4^x6', 'x2^x3^x5^x6^x7', 'x2^x4^x5^x6^x7', 'x3^x4^x5^x6^x7', 'x1^x2^x3^x4^x7', 'x1^x2^x4^x5^x6', 'x1^x2^x4^x6^x7', 'x2^x3^x4^x6^x7', 'x1^x3^x4^x6^x7', 'x1^x2^x3^x6^x7', 'x1^x3^x5^x6^x7'}
# image {'x1x2x3x5x7', 'x1x2x3x4x7 + x1x2x5x6x7', 'x1x3x4x6x7', 'x1x2x4x6x7', 'x1x3x5x6x7', 'x1x2x4x5x7', 'x1x4x5x6x7', 'x1x2x3x4x7 + x3x4x5x6x7', 'x2x3x4x6x7', 'x2x4x5x6x7', 'x2x3x5x6x7'}
# The claim is not satisfied for p=1 for L17 because of duplicates.
# codomain {'x1^x2^x3^x4^x6^x7', 'x1^x2^x4^x5^x6^x7', 'x1^x2^x3^x4^x5^x7', 'x1^x3^x4^x5^x6^x7', 'x1^x2^x3^x4^x5^x6', 'x2^x3^x4^x5^x6^x7'}
# image {'-2 x1x2x4x5x6x7', '-2 x1x2x3x5x6x7', '-2 x2x3x4x5x6x7', '-2 x1x2x3x4x6x7', '-2 x1x3x4x5x6x7'}
# The claim is not satisfied for p=2 for L17 because of duplicates.
# codomain {'x1^x3^x4^x5', 'x1^x3^x4^x7', 'x2^x5^x6^x7', 'x1^x3^x5^x6', 'x1^x2^x4^x6', 'x1^x3^x5^x7', 'x1^x2^x3^x7', 'x1^x2^x5^x7', 'x2^x4^x5^x7', 'x1^x3^x4^x6', 'x1^x4^x5^x7'}
# image {'-x1x4x5x7', '-x1x2x3x7'}
# The claim is not satisfied for p=0 for L157 because of duplicates.
# codomain {'x1^x2^x3^x4^x5', 'x2^x3^x4^x5^x7', 'x1^x2^x3^x4^x6', 'x2^x4^x5^x6^x7', 'x3^x4^x5^x6^x7', 'x1^x2^x4^x6^x7', 'x2^x3^x4^x6^x7', 'x1^x3^x4^x6^x7', 'x1^x2^x3^x6^x7', 'x1^x3^x5^x6^x7'}
# image {'x1x2x5x6x7', 'x1x3x4x6x7', '-x1x2x3x6x7', 'x1x2x4x6x7', '-x1x2x3x4x7 + x1x3x5x6x7', 'x1x3x4x5x7'}
# The claim is not satisfied for p=1 for L157 because of duplicates.
# codomain {'x1^x2^x3^x4^x6^x7', 'x1^x2^x4^x5^x6^x7', 'x1^x2^x3^x4^x5^x7', 'x1^x3^x4^x5^x6^x7', 'x1^x2^x3^x4^x5^x6'}
# image {'-2 x1x2x4x5x6x7', '2 x1x2x3x4x6x7', '-2 x1x3x4x5x6x7'}
# The claim is not satisfied for p=2 for L157 because of duplicates.
# codomain {'x2^x5^x6^x7', 'x1^x3^x6^x7', 'x2^x3^x5^x7', 'x1^x4^x6^x7', 'x1^x3^x5^x6', 'x1^x2^x4^x5', 'x3^x5^x6^x7', 'x1^x2^x3^x7', 'x1^x4^x5^x7'}
# image {'-x2x3x5x7', '-x2x4x6x7', '-x1x4x5x7'}
# The claim is not satisfied for p=0 for L147A because of duplicates.
# codomain {'x1^x2^x3^x4^x5', 'x1^x2^x3^x5^x6', 'x1^x2^x3^x4^x6', 'x2^x3^x5^x6^x7', 'x2^x4^x5^x6^x7', 'x2^x3^x4^x6^x7', 'x1^x3^x4^x6^x7', 'x1^x2^x3^x6^x7'}
# image {'x1x2x3x4x7', 'x1x2x3x6x7', 'x1x3x5x6x7', 'x1x2x5x6x7 + x1x3x4x6x7'}
# The claim is not satisfied for p=1 for L147A because of duplicates.
# codomain {'x1^x3^x4^x5^x6^x7', 'x1^x2^x4^x5^x6^x7', 'x2^x3^x4^x5^x6^x7', 'x1^x2^x3^x4^x5^x7'}
# image {'-2 x1x2x3x5x6x7', '-2 x1x2x3x4x5x7', '2 x1x2x3x4x6x7'}
# The claim is not satisfied for p=2 for L147A because of duplicates.
# codomain {'x2^x5^x6^x7', 'x4^x5^x6^x7', 'x1^x3^x6^x7', 'x2^x3^x5^x7', 'x1^x4^x6^x7', 'x1^x3^x5^x6', 'x1^x2^x4^x5', 'x1^x2^x3^x7', 'x1^x2^x5^x7'}
# image {'-x1x4x5x7', '-x2x4x6x7'}
# The claim is not satisfied for p=0 for L147A1 because of duplicates.
# codomain {'x1^x2^x3^x4^x5', 'x1^x2^x3^x5^x6', 'x1^x2^x3^x4^x6', 'x2^x3^x5^x6^x7', 'x2^x4^x5^x6^x7', 'x2^x3^x4^x6^x7', 'x1^x3^x4^x6^x7', 'x1^x2^x3^x6^x7'}
# image {'x1x2x3x5x7', 'x1x2x3x6x7', 'x1x3x5x6x7 - x2x3x4x5x7', 'x1x2x4x6x7 + x1x3x5x6x7'}
# The claim is not satisfied for p=1 for L147A1 because of duplicates.
# codomain {'x1^x3^x4^x5^x6^x7', 'x1^x2^x4^x5^x6^x7', 'x2^x3^x4^x5^x6^x7', 'x1^x2^x3^x4^x5^x7'}
# image {'2 x1x2x3x5x6x7', '-2 x1x2x3x4x6x7', '2 x1x2x3x4x5x7'}
# The claim is not satisfied for p=2 for L147A1 because of duplicates.
# codomain {'x1^x3^x4^x7', 'x2^x3^x4^x5', 'x1^x3^x6^x7', 'x1^x4^x6^x7', 'x1^x3^x5^x6', 'x1^x2^x4^x5', 'x1^x3^x5^x7', 'x1^x2^x3^x7', 'x2^x4^x5^x7', 'x1^x4^x5^x7'}
# image {'-x1x4x5x7'}
# The claim is not satisfied for p=0 for L147B because of duplicates.
# codomain {'x1^x2^x3^x4^x5', 'x1^x2^x3^x5^x6', 'x1^x2^x3^x4^x6', 'x2^x3^x5^x6^x7', 'x2^x4^x5^x6^x7', 'x1^x2^x4^x6^x7', 'x1^x3^x4^x6^x7', 'x1^x2^x3^x6^x7'}
# image {'x1x2x3x4x7', 'x1x2x3x5x7', 'x1x3x5x6x7', '-x1x3x4x5x7 + x2x3x5x6x7'}
# The claim is not satisfied for p=1 for L147B because of duplicates.
# codomain {'x1^x3^x4^x5^x6^x7', 'x1^x2^x4^x5^x6^x7', 'x2^x3^x4^x5^x6^x7', 'x1^x2^x3^x4^x5^x7'}
# image {'-2 x1x2x3x5x6x7', '-2 x1x2x3x4x5x7', '2 x1x2x3x4x6x7'}
# The claim is not satisfied for p=2 for L147B because of duplicates.
# codomain {'x1^x3^x4^x7', 'x2^x5^x6^x7', 'x1^x3^x5^x6', 'x1^x2^x4^x6', 'x1^x2^x4^x5', 'x3^x4^x5^x6', 'x1^x2^x3^x7', 'x1^x2^x5^x7', 'x3^x5^x6^x7'}
# image {'-x2x3x5x7'}
# The claim is not satisfied for p=0 for L147D because of duplicates.
# codomain {'x1^x2^x3^x4^x5', 'x1^x2^x3^x5^x6', 'x1^x2^x3^x4^x6', 'x2^x3^x5^x6^x7', 'x1^x2^x4^x6^x7', 'x2^x3^x4^x6^x7', 'x1^x2^x3^x6^x7'}
# image {'-2 x1x2x3x4x7', 'x1x2x3x5x7 + x1x2x3x6x7', 'x1x3x5x6x7 + x2x3x5x6x7'}
# The claim is not satisfied for p=1 for L147D because of duplicates.
# codomain {'x1^x3^x4^x5^x6^x7', 'x2^x3^x4^x5^x6^x7', 'x1^x2^x3^x4^x5^x7'}
# image {'2 x1x2x3x5x6x7', '-4 x1x2x3x4x5x7 - 4 x1x2x3x4x6x7'}
# The claim is not satisfied for p=2 for L147D because of duplicates.
# codomain {'x1^x3^x4^x7', 'x4^x5^x6^x7', 'x1^x3^x6^x7', 'x1^x3^x5^x6', 'x1^x3^x5^x7', 'x3^x4^x5^x6', 'x2^x4^x5^x7', 'x1^x3^x4^x6'}
# image {'-x1x3x4x7', '-x1x2x3x7'}
# The claim is not satisfied for p=0 for L1457B because of duplicates.
# codomain {'x1^x2^x3^x4^x5', 'x1^x2^x3^x4^x6', 'x2^x4^x5^x6^x7', 'x3^x4^x5^x6^x7', 'x1^x2^x4^x6^x7', 'x1^x3^x4^x6^x7'}
# image {'x1x3x5x6x7', 'x1x2x3x6x7'}
# The claim is not satisfied for p=1 for L1457B because of duplicates.
# codomain {'x1^x3^x4^x5^x6^x7', 'x1^x2^x3^x4^x6^x7', 'x1^x2^x4^x5^x6^x7', 'x1^x2^x3^x4^x5^x7'}
# image {'-2 x1x2x3x5x6x7'}
# The claim is not satisfied for p=2 for L1457B because of duplicates.
# codomain {'x1^x3^x4^x7', 'x2^x5^x6^x7', 'x1^x3^x6^x7', 'x1^x3^x5^x6', 'x1^x2^x4^x6', 'x1^x4^x5^x7', 'x1^x2^x3^x5'}
# image {'-x2x3x6x7'}
# The claim is not satisfied for p=0 for L137B because of duplicates.
# codomain {'x1^x2^x3^x5^x6', 'x1^x2^x3^x4^x6', 'x2^x4^x5^x6^x7', 'x1^x2^x3^x4^x7', 'x2^x3^x4^x6^x7', 'x1^x2^x3^x6^x7', 'x1^x3^x5^x6^x7'}
# image {'x1x2x3x6x7', '-x1x3x4x6x7', 'x1x3x4x5x7', '-x1x4x5x6x7'}
# The claim is not satisfied for p=1 for L137B because of duplicates.
# codomain {'x1^x3^x4^x5^x6^x7', 'x1^x2^x3^x4^x5^x6', 'x2^x3^x4^x5^x6^x7', 'x1^x2^x3^x4^x5^x7'}
# image {'-2 x1x2x3x4x5x7', '-2 x1x2x3x5x6x7', '2 x1x3x4x5x6x7'}
# The claim is not satisfied for p=2 for L137B because of duplicates.
# codomain {'x1^x3^x4^x7', 'x2^x5^x6^x7', 'x1^x3^x6^x7', 'x1^x3^x5^x6', 'x2^x3^x6^x7', 'x3^x4^x5^x6', 'x1^x4^x5^x7'}
# image {'-x2x3x4x7'}
# The claim is not satisfied for p=0 for L137B1 because of duplicates.
# codomain {'x1^x2^x4^x5^x7', 'x1^x2^x3^x5^x6', 'x2^x3^x5^x6^x7', 'x2^x4^x5^x6^x7', 'x1^x2^x4^x5^x6', 'x1^x2^x4^x6^x7', 'x1^x2^x3^x6^x7'}
# image {'x1x2x3x4x7', 'x1x2x4x5x7', 'x1x2x3x5x7'}
# The claim is not satisfied for p=1 for L137B1 because of duplicates.
# codomain {'x1^x3^x4^x5^x6^x7', 'x1^x2^x3^x4^x5^x6', 'x2^x3^x4^x5^x6^x7', 'x1^x2^x3^x4^x5^x7'}
# image {'2 x1x2x3x5x6x7', '2 x1x2x3x4x5x7', '2 x1x2x4x5x6x7'}
# The claim is not satisfied for p=2 for L137B1 because of duplicates.
# codomain {'x2^x3^x5^x6', 'x1^x3^x4^x7', 'x1^x3^x6^x7', 'x1^x3^x5^x7', 'x1^x2^x4^x6', 'x3^x4^x5^x6', 'x1^x4^x5^x7', 'x1^x2^x3^x5'}
# image {'-x2x4x5x7'}
# The claim is not satisfied for p=0 for L137D because of duplicates.
# codomain {'x1^x2^x3^x4^x5', 'x1^x2^x3^x4^x6', 'x2^x4^x5^x6^x7', 'x1^x2^x3^x4^x7', 'x1^x2^x4^x5^x6', 'x1^x3^x4^x6^x7', 'x1^x2^x3^x6^x7'}
# image {'-x1x2x3x5x7', 'x1x3x4x6x7', 'x1x3x4x5x7', 'x1x2x4x6x7 + x2x3x4x5x7'}
# The claim is not satisfied for p=1 for L137D because of duplicates.
# codomain {'x1^x3^x4^x5^x6^x7', 'x1^x2^x3^x4^x5^x6', 'x2^x3^x4^x5^x6^x7', 'x1^x2^x3^x4^x5^x7'}
# image {'-2 x1x2x3x4x6x7', '-2 x1x2x3x5x6x7', '2 x1x3x4x5x6x7'}
# The claim is not satisfied for p=2 for L137D because of duplicates.
# codomain {'x1^x4^x5^x6', 'x1^x3^x5^x6', 'x1^x2^x4^x6', 'x3^x4^x5^x6', 'x1^x2^x3^x7', 'x1^x3^x4^x6', 'x1^x4^x5^x7', 'x1^x2^x3^x5'}
# image {'-x1x2x3x7'}
# The claim is not satisfied for p=0 for L1357A because of duplicates.
# codomain {'x1^x2^x3^x4^x5', 'x1^x4^x5^x6^x7', 'x1^x2^x3^x5^x6', 'x2^x4^x5^x6^x7', 'x1^x2^x3^x4^x7', 'x1^x2^x4^x6^x7', 'x1^x2^x3^x6^x7'}
# image {'-x1x3x4x6x7', '-x1x2x3x4x7', '-x1x2x4x6x7'}
# The claim is not satisfied for p=1 for L1357A because of duplicates.
# codomain {'x1^x3^x4^x5^x6^x7', 'x1^x2^x4^x5^x6^x7', 'x2^x3^x4^x5^x6^x7', 'x1^x2^x3^x4^x5^x7'}
# image {'2 x1x2x3x5x6x7', '-2 x1x2x3x4x5x7', '2 x1x2x3x4x6x7'}
# The claim is not satisfied for p=2 for L1357A because of duplicates.
# codomain {'x1^x3^x5^x6', 'x1^x2^x4^x6', 'x3^x4^x5^x6', 'x1^x2^x3^x7', 'x1^x3^x4^x6', 'x1^x4^x5^x7', 'x1^x2^x3^x5'}
# image {'-x1x2x3x7'}
# The claim is not satisfied for p=0 for L1357C because of duplicates.
# codomain {'x1^x2^x3^x4^x5', 'x1^x2^x3^x5^x6', 'x2^x4^x5^x6^x7', 'x1^x2^x3^x4^x7', 'x1^x2^x4^x6^x7', 'x1^x2^x3^x6^x7'}
# image {'x1x2x4x6x7 - x1x3x4x6x7', '-x1x3x4x6x7', '-x1x2x3x4x7 + x1x2x3x6x7'}
# The claim is not satisfied for p=1 for L1357C because of duplicates.
# codomain {'x1^x3^x4^x5^x6^x7', 'x1^x2^x4^x5^x6^x7', 'x2^x3^x4^x5^x6^x7', 'x1^x2^x3^x4^x5^x7'}
# image {'2 x1x2x3x4x6x7', '-2 x1x2x3x4x5x7', '-2 x1x2x3x4x5x7 - 2 x1x2x3x5x6x7'}
# The claim is not satisfied for p=2 for L1357C because of duplicates.
# codomain {'x1^x3^x4^x7', 'x1^x4^x5^x6', 'x2^x3^x4^x6', 'x2^x3^x5^x7', 'x1^x2^x4^x6', 'x1^x2^x5^x7', 'x2^x4^x6^x7', 'x1^x4^x5^x7'}
# image {'-x2x5x6x7', '-x1x3x4x7', '-x2x4x6x7'}
# The claim is not satisfied for p=0 for L1357D because of duplicates.
# codomain {'x1^x2^x3^x4^x5', 'x1^x2^x3^x4^x6', 'x1^x2^x5^x6^x7', 'x1^x2^x3^x4^x7', 'x2^x3^x4^x6^x7', 'x1^x3^x5^x6^x7'}
# image {'x1x2x5x6x7 + x2x3x4x5x7', '-x2x4x5x6x7', '-x1x2x4x5x7'}
# The claim is not satisfied for p=1 for L1357D because of duplicates.
# codomain {'x1^x3^x4^x5^x6^x7', 'x1^x2^x3^x4^x5^x6', 'x1^x2^x3^x4^x5^x7'}
# image {'-2 x1x2x4x5x6x7'}
# The claim is not satisfied for p=2 for L1357D because of duplicates.
# codomain {'x1^x3^x4^x7', 'x2^x3^x4^x5', 'x2^x3^x4^x6', 'x1^x4^x6^x7', 'x1^x2^x4^x6', 'x1^x2^x3^x7', 'x1^x2^x5^x7'}
# image {'-x2x5x6x7'}
# The claim is not satisfied for p=0 for L1357F because of duplicates.
# codomain {'x1^x2^x3^x4^x5', 'x1^x2^x3^x4^x6', 'x1^x2^x4^x6^x7', 'x2^x3^x4^x6^x7', 'x1^x3^x5^x6^x7'}
# image {'x1x3x4x6x7 - x2x4x5x6x7'}
# The claim is not satisfied for p=1 for L1357F because of duplicates.
# codomain {'x1^x3^x4^x5^x6^x7', 'x1^x2^x3^x4^x5^x6', 'x1^x2^x3^x4^x5^x7'}
# image {'-2 x1x2x3x4x5x7'}
# The claim is not satisfied for p=2 for L1357F because of duplicates.
# codomain {'x1^x3^x4^x7', 'x2^x3^x4^x5', 'x2^x3^x4^x6', 'x1^x4^x6^x7', 'x1^x2^x4^x6', 'x1^x2^x3^x7', 'x1^x2^x5^x7'}
# image {'-x2x5x6x7'}
# The claim is not satisfied for p=0 for L1357F1 because of duplicates.
# codomain {'x1^x2^x3^x4^x5', 'x1^x2^x3^x4^x6', 'x1^x2^x4^x6^x7', 'x2^x3^x4^x6^x7', 'x1^x3^x5^x6^x7'}
# image {'x1x3x4x6x7 - x2x4x5x6x7'}
# The claim is not satisfied for p=1 for L1357F1 because of duplicates.
# codomain {'x1^x3^x4^x5^x6^x7', 'x1^x2^x3^x4^x5^x6', 'x1^x2^x3^x4^x5^x7'}
# image {'-2 x1x2x3x4x5x7'}
# The claim is not satisfied for p=2 for L1357F1 because of duplicates.
# codomain {'x1^x3^x4^x7', 'x1^x4^x5^x6', 'x2^x3^x5^x7', 'x1^x2^x4^x6', 'x3^x4^x5^x6', 'x1^x4^x5^x7', 'x3^x4^x5^x7'}
# image {'-x2x4x6x7', '-x1x2x4x7'}
# The claim is not satisfied for p=0 for L1357H because of duplicates.
# codomain {'x1^x2^x3^x4^x5', 'x1^x4^x5^x6^x7', 'x1^x2^x3^x4^x6', 'x1^x2^x3^x4^x7', 'x1^x2^x3^x6^x7', 'x1^x3^x5^x6^x7'}
# image {'-x2x4x5x6x7', '-x1x2x4x5x7 - x1x2x4x6x7', '-x1x2x3x4x7'}
# The claim is not satisfied for p=1 for L1357H because of duplicates.
# codomain {'x1^x3^x4^x5^x6^x7', 'x1^x2^x3^x4^x5^x6', 'x1^x2^x3^x4^x5^x7'}
# image {'-2 x1x2x4x5x6x7'}
# The claim is not satisfied for p=2 for L1357H because of duplicates.
# codomain {'x1^x3^x4^x7', 'x2^x3^x4^x5', 'x2^x3^x4^x6', 'x1^x2^x4^x6', 'x3^x4^x5^x6', 'x3^x4^x5^x7'}
# image set()
# The claim is not satisfied for p=0 for L1357J because of duplicates.
# codomain {'x1^x2^x3^x4^x6', 'x1^x2^x4^x6^x7', 'x1^x2^x4^x5^x6', 'x1^x2^x3^x6^x7', 'x1^x3^x5^x6^x7'}
# image {'x1x2x4x6x7', 'x1x3x4x6x7 - x2x4x5x6x7'}
# The claim is not satisfied for p=1 for L1357J because of duplicates.
# codomain {'x1^x3^x4^x5^x6^x7', 'x1^x2^x3^x4^x5^x6', 'x1^x2^x3^x4^x5^x7'}
# image {'-2 x1x2x3x4x5x7'}
# The claim is not satisfied for p=2 for L1357J because of duplicates.
# codomain {'x1^x3^x4^x7', 'x2^x5^x6^x7', 'x2^x3^x5^x7', 'x1^x4^x6^x7', 'x1^x3^x5^x6', 'x3^x4^x5^x6', 'x1^x3^x4^x6', 'x1^x4^x5^x7'}
# image {'-x1x2x3x7', '-x1x2x4x7'}
# The claim is not satisfied for p=0 for L1357L because of duplicates.
# codomain {'x1^x2^x3^x4^x5', 'x1^x4^x5^x6^x7', 'x2^x4^x5^x6^x7', 'x1^x2^x4^x6^x7', 'x1^x2^x3^x6^x7', 'x1^x3^x5^x6^x7'}
# image {'-x1x4x5x6x7 + x2x3x4x6x7', 'x1x2x3x6x7 + 1/2 x1x3x4x6x7', '1/2 x1x2x3x4x7'}
# The claim is not satisfied for p=1 for L1357L because of duplicates.
# codomain {'x1^x3^x4^x5^x6^x7', 'x1^x2^x3^x4^x5^x6', 'x1^x2^x3^x4^x5^x7'}
# image {'2 x1x2x3x4x5x7 + x1x2x4x5x6x7'}
# The claim is not satisfied for p=2 for L1357L because of duplicates.
# codomain {'x1^x3^x4^x7', 'x2^x5^x6^x7', 'x2^x3^x4^x6', 'x2^x3^x5^x7', 'x1^x3^x5^x6', 'x3^x4^x5^x6', 'x1^x4^x5^x7'}
# image {'-x1x2x4x7'}
# The claim is not satisfied for p=0 for L1357P because of duplicates.
# codomain {'x1^x2^x3^x4^x5', 'x1^x4^x5^x6^x7', 'x1^x2^x5^x6^x7', 'x1^x2^x4^x6^x7', 'x2^x3^x4^x6^x7', 'x1^x2^x3^x6^x7'}
# image {'x1x2x3x4x7'}
# The claim is not satisfied for p=1 for L1357P because of duplicates.
# codomain {'x1^x3^x4^x5^x6^x7', 'x1^x2^x3^x4^x5^x6', 'x1^x2^x3^x4^x5^x7'}
# image {'2 x1x2x4x5x6x7'}
# The claim is not satisfied for p=2 for L1357P because of duplicates.
# codomain {'x1^x3^x4^x7', 'x2^x5^x6^x7', 'x2^x3^x4^x6', 'x2^x3^x5^x7', 'x1^x3^x5^x6', 'x3^x4^x5^x6', 'x1^x4^x5^x7'}
# image {'-x1x2x4x7'}
# The claim is not satisfied for p=0 for L1357P1 because of duplicates.
# codomain {'x1^x2^x3^x4^x5', 'x1^x4^x5^x6^x7', 'x1^x2^x5^x6^x7', 'x1^x2^x4^x6^x7', 'x2^x3^x4^x6^x7', 'x1^x2^x3^x6^x7'}
# image {'x1x2x3x4x7'}
# The claim is not satisfied for p=1 for L1357P1 because of duplicates.
# codomain {'x1^x3^x4^x5^x6^x7', 'x1^x2^x3^x4^x5^x6', 'x1^x2^x3^x4^x5^x7'}
# image {'-2 x1x2x4x5x6x7'}
# The claim is not satisfied for p=2 for L1357P1 because of duplicates.
# codomain {'x1^x3^x4^x7', 'x2^x3^x4^x6', 'x1^x3^x6^x7', 'x2^x3^x5^x7', 'x1^x3^x5^x6', 'x1^x2^x3^x7', 'x1^x4^x5^x7'}
# image {'-x1x4x5x7', '-x2x4x6x7', '-x1x2x4x7'}
# The claim is not satisfied for p=0 for L1357R because of duplicates.
# codomain {'x1^x2^x3^x4^x5', 'x1^x4^x5^x6^x7', 'x1^x2^x5^x6^x7', 'x2^x3^x4^x6^x7', 'x1^x3^x4^x6^x7', 'x1^x2^x3^x6^x7'}
# image {'x1x2x3x4x7'}
# The claim is not satisfied for p=1 for L1357R because of duplicates.
# codomain {'x1^x3^x4^x5^x6^x7', 'x1^x2^x3^x4^x5^x6', 'x1^x2^x3^x4^x5^x7'}
# image {'-2 x1x2x4x5x6x7'}
# The claim is not satisfied for p=2 for L1357R because of duplicates.
# codomain {'x1^x3^x5^x6', 'x1^x2^x3^x7', 'x1^x4^x5^x7', 'x1^x4^x6^x7'}
# image {'-x1x4x5x7'}
# The claim is not satisfied for p=0 for L13457C because of duplicates.
# codomain {'x2^x4^x5^x6^x7', 'x1^x3^x4^x6^x7', 'x1^x2^x3^x4^x5', 'x1^x2^x4^x5^x6'}
# image {'x1x2x5x6x7 - x1x3x4x6x7'}
# The claim is not satisfied for p=1 for L13457C because of duplicates.
# codomain {'x1^x3^x4^x5^x6^x7', 'x1^x2^x4^x5^x6^x7', 'x1^x2^x3^x4^x5^x7'}
# image {'2 x1x2x3x4x5x7'}
# The claim is not satisfied for p=2 for L13457C because of duplicates.
# codomain {'x1^x3^x5^x6', 'x1^x2^x3^x7', 'x1^x4^x5^x7', 'x1^x4^x6^x7'}
# image set()
# The claim is not satisfied for p=0 for L13457E because of duplicates.
# codomain {'x2^x4^x5^x6^x7', 'x1^x3^x4^x6^x7', 'x1^x2^x3^x4^x5', 'x1^x2^x4^x5^x6'}
# image {'x1x2x5x6x7 - x1x3x4x6x7'}
# The claim is not satisfied for p=1 for L13457E because of duplicates.
# codomain {'x1^x3^x4^x5^x6^x7', 'x1^x2^x4^x5^x6^x7', 'x1^x2^x3^x4^x5^x7'}
# image {'2 x1x2x3x4x5x7'}
# The claim is not satisfied for p=2 for L13457E because of duplicates.
# codomain {'x1^x3^x5^x6', 'x1^x3^x6^x7', 'x1^x2^x3^x7', 'x1^x4^x6^x7'}
# image {'-x1x4x5x7'}
# The claim is not satisfied for p=0 for L13457G because of duplicates.
# codomain {'x1^x3^x4^x6^x7', 'x1^x2^x3^x4^x5', 'x1^x2^x4^x5^x6'}
# image set()
# The claim is not satisfied for p=1 for L13457G because of duplicates.
# codomain {'x1^x3^x4^x5^x6^x7', 'x1^x2^x3^x4^x5^x7'}
# image set()
# The claim is not satisfied for p=2 for L13457G because of duplicates.
# codomain {'x1^x3^x5^x6', 'x1^x2^x4^x6', 'x1^x3^x6^x7', 'x1^x2^x3^x7'}
# image set()
# The claim is not satisfied for p=0 for L13457I because of duplicates.
# codomain {'x1^x2^x4^x6^x7', 'x1^x2^x3^x4^x5', 'x1^x2^x4^x5^x6'}
# image set()
# The claim is not satisfied for p=1 for L13457I because of duplicates.
# codomain {'x1^x3^x4^x5^x6^x7', 'x1^x2^x3^x4^x5^x7'}
# image set()
# The claim is not satisfied for p=2 for L13457I because of duplicates.
# codomain {'x1^x2^x4^x6', 'x1^x3^x4^x7', 'x2^x5^x6^x7', 'x1^x4^x6^x7'}
# image set()
# The claim is not satisfied for p=0 for L12457D because of duplicates.
# codomain {'x1^x2^x4^x6^x7', 'x2^x4^x5^x6^x7', 'x1^x2^x4^x5^x6', 'x1^x2^x3^x4^x6'}
# image set()
# The claim is not satisfied for p=1 for L12457D because of duplicates.
# codomain {'x1^x3^x4^x5^x6^x7', 'x1^x2^x3^x4^x6^x7', 'x1^x2^x3^x4^x5^x7'}
# image set()
# The claim is not satisfied for p=2 for L12457D because of duplicates.
# codomain {'x1^x3^x4^x7', 'x2^x5^x6^x7', 'x2^x3^x4^x5', 'x1^x3^x5^x7', 'x3^x4^x5^x6', 'x2^x4^x5^x7'}
# image set()
# The claim is not satisfied for p=0 for L12457E because of duplicates.
# codomain {'x1^x2^x3^x4^x5', 'x1^x4^x5^x6^x7', 'x1^x2^x3^x4^x6', 'x2^x4^x5^x6^x7', 'x1^x3^x4^x6^x7'}
# image set()
# The claim is not satisfied for p=1 for L12457E because of duplicates.
# codomain {'x1^x3^x4^x5^x6^x7', 'x1^x2^x3^x4^x6^x7', 'x1^x2^x3^x4^x5^x7'}
# image set()
# The claim is not satisfied for p=2 for L12457E because of duplicates.
# codomain {'x1^x2^x4^x6', 'x1^x3^x4^x7', 'x2^x5^x6^x7', 'x1^x4^x6^x7'}
# image set()
# The claim is not satisfied for p=0 for L12457G because of duplicates.
# codomain {'x1^x2^x4^x6^x7', 'x2^x4^x5^x6^x7', 'x1^x2^x4^x5^x6', 'x1^x2^x3^x4^x6'}
# image set()
# The claim is not satisfied for p=1 for L12457G because of duplicates.
# codomain {'x1^x3^x4^x5^x6^x7', 'x1^x2^x3^x4^x6^x7', 'x1^x2^x3^x4^x5^x7'}
# image set()
# The claim is not satisfied for p=2 for L12457G because of duplicates.
# codomain {'x1^x3^x4^x7', 'x2^x5^x6^x7', 'x2^x3^x4^x5', 'x2^x3^x4^x6', 'x1^x2^x5^x7', 'x2^x4^x6^x7'}
# image {'-x2x5x6x7', '-x1x3x4x7'}
# The claim is not satisfied for p=0 for L12457I because of duplicates.
# codomain {'x2^x3^x5^x6^x7', 'x2^x3^x4^x6^x7', 'x1^x2^x3^x4^x6'}
# image set()
# The claim is not satisfied for p=1 for L12457I because of duplicates.
# codomain {'x1^x3^x4^x5^x6^x7', 'x1^x2^x3^x4^x5^x7'}
# image set()
# The claim is not satisfied for p=2 for L12457I because of duplicates.
# codomain {'x1^x3^x4^x7', 'x2^x3^x4^x6', 'x1^x4^x6^x7', 'x1^x3^x5^x7', 'x1^x2^x5^x7'}
# image {'-x2x5x6x7'}
# The claim is not satisfied for p=0 for L12457J because of duplicates.
# codomain {'x2^x3^x5^x6^x7', 'x1^x2^x4^x6^x7', 'x1^x2^x3^x4^x6'}
# image set()
# The claim is not satisfied for p=1 for L12457J because of duplicates.
# codomain {'x1^x3^x4^x5^x6^x7', 'x1^x2^x3^x4^x5^x7'}
# image set()
# The claim is not satisfied for p=2 for L12457J because of duplicates.
# codomain {'x1^x3^x4^x7', 'x2^x3^x4^x6', 'x1^x4^x6^x7', 'x1^x3^x5^x7', 'x1^x2^x5^x7'}
# image {'-x2x5x6x7'}
# The claim is not satisfied for p=0 for L12457J1 because of duplicates.
# codomain {'x2^x3^x5^x6^x7', 'x1^x2^x4^x6^x7', 'x1^x2^x3^x4^x6'}
# image set()
# The claim is not satisfied for p=1 for L12457J1 because of duplicates.
# codomain {'x1^x3^x4^x5^x6^x7', 'x1^x2^x3^x4^x5^x7'}
# image set()
# The claim is not satisfied for p=2 for L12457J1 because of duplicates.
# codomain {'x3^x4^x5^x6', 'x2^x5^x6^x7', 'x1^x2^x5^x7', 'x1^x3^x4^x7'}
# image set()
# The claim is not satisfied for p=0 for L12457L because of duplicates.
# codomain {'x2^x3^x4^x6^x7', 'x1^x2^x3^x4^x5', 'x1^x2^x3^x4^x6'}
# image set()
# The claim is not satisfied for p=1 for L12457L because of duplicates.
# codomain {'x1^x3^x4^x5^x6^x7', 'x1^x2^x3^x4^x5^x7'}
# image set()
# The claim is not satisfied for p=2 for L12457L because of duplicates.
# codomain {'x1^x2^x4^x6', 'x3^x4^x5^x6', 'x1^x2^x3^x5', 'x1^x4^x6^x7'}
# image set()
# The claim is not satisfied for p=0 for L12357C because of duplicates.
# codomain {'x1^x2^x3^x6^x7', 'x2^x4^x5^x6^x7', 'x1^x2^x3^x4^x7', 'x1^x4^x5^x6^x7'}
# image {'-x1x2x3x5x7', 'x1x3x4x5x7'}
# The claim is not satisfied for p=1 for L12357C because of duplicates.
# codomain {'x1^x3^x4^x5^x6^x7', 'x2^x3^x4^x5^x6^x7', 'x1^x2^x3^x4^x5^x7'}
# image {'-2 x1x2x3x4x6x7', '-2 x1x2x3x5x6x7'}
# The claim is not satisfied for p=2 for L12357C because of duplicates.
# codomain {'x1^x3^x5^x6', 'x3^x4^x5^x6', 'x1^x2^x3^x7', 'x1^x4^x6^x7'}
# image set()
# The claim is not satisfied for p=0 for L123457C because of duplicates.
# codomain {'x2^x4^x5^x6^x7', 'x1^x4^x5^x6^x7', 'x1^x2^x3^x4^x6'}
# image {'x1x2x5x6x7 - x1x3x4x6x7'}
# The claim is not satisfied for p=1 for L123457C because of duplicates.
# codomain {'x1^x3^x4^x5^x6^x7', 'x1^x2^x3^x4^x5^x7'}
# image set()
# The claim is not satisfied for p=2 for L123457C because of duplicates.
# codomain {'x1^x3^x5^x6', 'x3^x4^x5^x6', 'x1^x2^x3^x7', 'x1^x4^x6^x7'}
# image set()
# The claim is not satisfied for p=0 for L123457F because of duplicates.
# codomain {'x2^x4^x5^x6^x7', 'x1^x4^x5^x6^x7', 'x1^x2^x3^x4^x6'}
# image set()
# The claim is not satisfied for p=1 for L123457F because of duplicates.
# codomain {'x1^x3^x4^x5^x6^x7', 'x1^x2^x3^x4^x5^x7'}
# image set()
# The claim is not satisfied for p=2 for L123457F because of duplicates.
# 35

# %%
not_okayB=[]
for L,dic in algebras_dics:
    if check_lefschetz_theoremB(L,dic)==False:
        not_okayB.append(L)
len(not_okayB)
# Out:
# codomain {'x1^x3^x4^x5', 'x1^x4^x5^x6', 'x1^x3^x5^x6', 'x1^x2^x4^x6', 'x1^x2^x4^x5', 'x3^x4^x5^x6'}
# image {'x2x3x4x6', 'x2x3x5x6', 'x1x3x5x6', 'x1x4x5x6', 'x1x3x4x6', 'x1x2x3x4 + x1x2x5x6', 'x1x2x4x5', 'x2x4x5x6', 'x1x2x3x5', 'x1x2x4x6', 'x1x2x3x4 + x3x4x5x6'}
# The claim is not satisfied for p=1 for L17 because of duplicates.
# codomain {'x1^x2^x4^x5^x6', 'x1^x2^x3^x4^x5', 'x1^x2^x3^x5^x6', 'x1^x2^x3^x4^x6'}
# image {'2 x1x2x4x5x6', '2 x1x2x3x5x6', '2 x1x3x4x5x6', '2 x2x3x4x5x6', '2 x1x2x3x4x6'}
# The claim is not satisfied for p=2 for L17 because of duplicates.
# codomain {'x1^x3^x5^x6', 'x1^x2^x4^x6', 'x1^x3^x4^x5', 'x1^x3^x4^x6'}
# image {'x1x3x4x6', '-x1x2x3x6', '-x1x2x3x4 + x1x3x5x6', 'x1x2x5x6', 'x1x3x4x5', 'x1x2x4x6'}
# The claim is not satisfied for p=1 for L157 because of duplicates.
# codomain {'x1^x2^x3^x4^x5', 'x1^x2^x3^x4^x6'}
# image {'-2 x1x2x3x4x6', '2 x1x2x4x5x6', '2 x1x3x4x5x6'}
# The claim is not satisfied for p=2 for L157 because of duplicates.
# codomain {'x1^x3^x5^x6', 'x1^x2^x4^x5'}
# image {'x1x2x3x4', 'x1x3x5x6', 'x1x2x5x6 + x1x3x4x6', 'x1x2x3x6'}
# The claim is not satisfied for p=1 for L147A because of duplicates.
# codomain {'x1^x2^x3^x4^x5', 'x1^x2^x3^x5^x6', 'x1^x2^x3^x4^x6'}
# image {'-2 x1x2x3x4x6', '2 x1x2x3x5x6', '2 x1x2x3x4x5'}
# The claim is satisfied for p=2 for L147A in terms of duplicates.
# codomain {'x1^x3^x5^x6', 'x1^x2^x4^x5'}
# image {'x1x3x5x6 - x2x3x4x5', 'x1x2x4x6 + x1x3x5x6', 'x1x2x3x6', 'x1x2x3x5'}
# The claim is not satisfied for p=1 for L147A1 because of duplicates.
# codomain {'x1^x2^x3^x4^x5', 'x1^x2^x3^x5^x6', 'x1^x2^x3^x4^x6'}
# image {'2 x1x2x3x4x6', '-2 x1x2x3x5x6', '-2 x1x2x3x4x5'}
# The claim is satisfied for p=2 for L147A1 in terms of duplicates.
# codomain {'x1^x3^x5^x6', 'x1^x2^x4^x5', 'x2^x3^x4^x5'}
# image {'x1x2x3x4', 'x1x3x5x6', 'x1x2x3x5', '-x1x3x4x5 + x2x3x5x6'}
# The claim is not satisfied for p=1 for L147B because of duplicates.
# codomain {'x1^x2^x3^x4^x5', 'x1^x2^x3^x5^x6', 'x1^x2^x3^x4^x6'}
# image {'-2 x1x2x3x4x6', '2 x1x2x3x5x6', '2 x1x2x3x4x5'}
# The claim is satisfied for p=2 for L147B in terms of duplicates.
# codomain {'x1^x3^x5^x6', 'x1^x2^x4^x6', 'x3^x4^x5^x6', 'x1^x2^x4^x5'}
# image {'x1x2x3x5 + x1x2x3x6', '-2 x1x2x3x4', 'x1x3x5x6 + x2x3x5x6'}
# The claim is not satisfied for p=1 for L147D because of duplicates.
# codomain {'x1^x2^x3^x4^x5', 'x1^x2^x3^x5^x6', 'x1^x2^x3^x4^x6'}
# image {'4 x1x2x3x4x5 + 4 x1x2x3x4x6', '-2 x1x2x3x5x6'}
# The claim is not satisfied for p=2 for L147D because of duplicates.
# codomain {'x1^x3^x5^x6', 'x1^x3^x4^x6', 'x3^x4^x5^x6'}
# image {'x1x2x3x6', 'x1x3x5x6'}
# The claim is not satisfied for p=1 for L1457B because of duplicates.
# codomain {'x1^x2^x3^x4^x5', 'x1^x2^x3^x4^x6'}
# image {'2 x1x2x3x5x6'}
# The claim is not satisfied for p=2 for L1457B because of duplicates.
# codomain {'x1^x3^x5^x6', 'x1^x2^x4^x6', 'x1^x2^x3^x5'}
# image {'-x1x4x5x6', '-x1x3x4x6', 'x1x2x3x6', 'x1x3x4x5'}
# The claim is not satisfied for p=1 for L137B because of duplicates.
# codomain {'x1^x2^x3^x5^x6', 'x1^x2^x3^x4^x6'}
# image {'-2 x1x3x4x5x6', '2 x1x2x3x5x6', '2 x1x2x3x4x5'}
# The claim is not satisfied for p=2 for L137B because of duplicates.
# codomain {'x1^x3^x5^x6', 'x3^x4^x5^x6'}
# image {'x1x2x3x4', 'x1x2x4x5', 'x1x2x3x5'}
# The claim is not satisfied for p=1 for L137B1 because of duplicates.
# codomain {'x1^x2^x3^x5^x6', 'x1^x2^x4^x5^x6'}
# image {'-2 x1x2x3x5x6', '-2 x1x2x3x4x5', '-2 x1x2x4x5x6'}
# The claim is not satisfied for p=2 for L137B1 because of duplicates.
# codomain {'x1^x2^x4^x6', 'x3^x4^x5^x6', 'x2^x3^x5^x6', 'x1^x2^x3^x5'}
# image {'x1x3x4x6', 'x1x3x4x5', 'x1x2x4x6 + x2x3x4x5', '-x1x2x3x5'}
# The claim is satisfied for p=1 for L137D in terms of duplicates.
# codomain {'x1^x2^x3^x4^x5', 'x1^x2^x4^x5^x6', 'x1^x2^x3^x4^x6'}
# image {'-2 x1x3x4x5x6', '2 x1x2x3x4x6', '2 x1x2x3x5x6'}
# The claim is satisfied for p=2 for L137D in terms of duplicates.
# Succes for L137D
# codomain {'x1^x4^x5^x6', 'x1^x3^x5^x6', 'x1^x2^x4^x6', 'x3^x4^x5^x6', 'x1^x3^x4^x6', 'x1^x2^x3^x5'}
# image {'-x1x2x4x6', '-x1x3x4x6', '-x1x2x3x4'}
# The claim is not satisfied for p=1 for L1357A because of duplicates.
# codomain {'x1^x2^x3^x4^x5', 'x1^x2^x3^x5^x6'}
# image {'-2 x1x2x3x4x6', '-2 x1x2x3x5x6', '2 x1x2x3x4x5'}
# The claim is not satisfied for p=2 for L1357A because of duplicates.
# codomain {'x1^x3^x5^x6', 'x1^x2^x4^x6', 'x3^x4^x5^x6', 'x1^x3^x4^x6', 'x1^x2^x3^x5'}
# image {'x1x2x4x6 - x1x3x4x6', '-x1x3x4x6', '-x1x2x3x4 + x1x2x3x6'}
# The claim is not satisfied for p=1 for L1357C because of duplicates.
# codomain {'x1^x2^x3^x4^x5', 'x1^x2^x3^x5^x6'}
# image {'-2 x1x2x3x4x6', '2 x1x2x3x4x5', '2 x1x2x3x4x5 + 2 x1x2x3x5x6'}
# The claim is not satisfied for p=2 for L1357C because of duplicates.
# codomain {'x1^x4^x5^x6', 'x2^x3^x4^x6', 'x1^x2^x4^x6'}
# image {'-x2x4x5x6', '-x1x2x4x5', 'x1x2x5x6 + x2x3x4x5'}
# The claim is satisfied for p=1 for L1357D in terms of duplicates.
# codomain {'x1^x2^x3^x4^x5', 'x1^x2^x3^x4^x6'}
# image {'2 x1x2x4x5x6'}
# The claim is not satisfied for p=2 for L1357D because of duplicates.
# codomain {'x2^x3^x4^x6', 'x1^x2^x4^x6', 'x2^x3^x4^x5'}
# image {'x1x3x4x6 - x2x4x5x6'}
# The claim is not satisfied for p=1 for L1357F because of duplicates.
# codomain {'x1^x2^x3^x4^x5', 'x1^x2^x3^x4^x6'}
# image {'2 x1x2x3x4x5'}
# The claim is not satisfied for p=2 for L1357F because of duplicates.
# codomain {'x2^x3^x4^x6', 'x1^x2^x4^x6', 'x2^x3^x4^x5'}
# image {'x1x3x4x6 - x2x4x5x6'}
# The claim is not satisfied for p=1 for L1357F1 because of duplicates.
# codomain {'x1^x2^x3^x4^x5', 'x1^x2^x3^x4^x6'}
# image {'2 x1x2x3x4x5'}
# The claim is not satisfied for p=2 for L1357F1 because of duplicates.
# codomain {'x1^x4^x5^x6', 'x1^x2^x4^x6', 'x3^x4^x5^x6'}
# image {'-x1x2x4x5 - x1x2x4x6', '-x2x4x5x6', '-x1x2x3x4'}
# The claim is satisfied for p=1 for L1357H in terms of duplicates.
# codomain {'x1^x2^x3^x4^x5', 'x1^x2^x3^x4^x6'}
# image {'2 x1x2x4x5x6'}
# The claim is not satisfied for p=2 for L1357H because of duplicates.
# codomain {'x1^x2^x4^x6', 'x3^x4^x5^x6', 'x2^x3^x4^x6', 'x2^x3^x4^x5'}
# image {'x1x2x4x6', 'x1x3x4x6 - x2x4x5x6'}
# The claim is not satisfied for p=1 for L1357J because of duplicates.
# codomain {'x1^x2^x4^x5^x6', 'x1^x2^x3^x4^x6'}
# image {'2 x1x2x3x4x5'}
# The claim is not satisfied for p=2 for L1357J because of duplicates.
# codomain {'x1^x3^x5^x6', 'x1^x3^x4^x6', 'x3^x4^x5^x6'}
# image {'1/2 x1x2x3x4', 'x1x2x3x6 + 1/2 x1x3x4x6', '-x1x4x5x6 + x2x3x4x6'}
# The claim is satisfied for p=1 for L1357L in terms of duplicates.
# codomain {'x1^x2^x3^x4^x5'}
# image {'-2 x1x2x3x4x5 - x1x2x4x5x6'}
# The claim is satisfied for p=2 for L1357L in terms of duplicates.
# Succes for L1357L
# codomain {'x1^x3^x5^x6', 'x2^x3^x4^x6', 'x3^x4^x5^x6'}
# image {'x1x2x3x4'}
# The claim is not satisfied for p=1 for L1357P because of duplicates.
# codomain {'x1^x2^x3^x4^x5'}
# image {'-2 x1x2x4x5x6'}
# The claim is satisfied for p=2 for L1357P in terms of duplicates.
# codomain {'x1^x3^x5^x6', 'x2^x3^x4^x6', 'x3^x4^x5^x6'}
# image {'x1x2x3x4'}
# The claim is not satisfied for p=1 for L1357P1 because of duplicates.
# codomain {'x1^x2^x3^x4^x5'}
# image {'2 x1x2x4x5x6'}
# The claim is satisfied for p=2 for L1357P1 in terms of duplicates.
# codomain {'x1^x3^x5^x6', 'x2^x3^x4^x6'}
# image {'x1x2x3x4'}
# The claim is not satisfied for p=1 for L1357R because of duplicates.
# codomain {'x1^x2^x3^x4^x5'}
# image {'2 x1x2x4x5x6'}
# The claim is satisfied for p=2 for L1357R in terms of duplicates.
# codomain {'x1^x3^x5^x6'}
# image {'x1x2x5x6 - x1x3x4x6'}
# The claim is satisfied for p=1 for L13457C in terms of duplicates.
# codomain {'x1^x2^x3^x4^x5', 'x1^x2^x4^x5^x6'}
# image {'-2 x1x2x3x4x5'}
# The claim is not satisfied for p=2 for L13457C because of duplicates.
# codomain {'x1^x3^x5^x6'}
# image {'x1x2x5x6 - x1x3x4x6'}
# The claim is satisfied for p=1 for L13457E in terms of duplicates.
# codomain {'x1^x2^x3^x4^x5', 'x1^x2^x4^x5^x6'}
# image {'-2 x1x2x3x4x5'}
# The claim is not satisfied for p=2 for L13457E because of duplicates.
# codomain {'x1^x3^x5^x6'}
# image set()
# The claim is not satisfied for p=1 for L13457G because of duplicates.
# codomain {'x1^x2^x3^x4^x5', 'x1^x2^x4^x5^x6'}
# image set()
# The claim is not satisfied for p=2 for L13457G because of duplicates.
# codomain {'x1^x3^x5^x6', 'x1^x2^x4^x6'}
# image set()
# The claim is not satisfied for p=1 for L13457I because of duplicates.
# codomain {'x1^x2^x3^x4^x5', 'x1^x2^x4^x5^x6'}
# image set()
# The claim is not satisfied for p=2 for L13457I because of duplicates.
# codomain {'x1^x2^x4^x6'}
# image set()
# The claim is not satisfied for p=1 for L12457D because of duplicates.
# codomain {'x1^x2^x4^x5^x6', 'x1^x2^x3^x4^x6'}
# image set()
# The claim is not satisfied for p=2 for L12457D because of duplicates.
# codomain {'x3^x4^x5^x6', 'x2^x3^x4^x5'}
# image set()
# The claim is not satisfied for p=1 for L12457E because of duplicates.
# codomain {'x1^x2^x3^x4^x5', 'x1^x2^x3^x4^x6'}
# image set()
# The claim is not satisfied for p=2 for L12457E because of duplicates.
# codomain {'x1^x2^x4^x6'}
# image set()
# The claim is not satisfied for p=1 for L12457G because of duplicates.
# codomain {'x1^x2^x4^x5^x6', 'x1^x2^x3^x4^x6'}
# image set()
# The claim is not satisfied for p=2 for L12457G because of duplicates.
# codomain {'x2^x3^x4^x6', 'x2^x3^x4^x5'}
# image set()
# The claim is not satisfied for p=1 for L12457I because of duplicates.
# codomain {'x1^x2^x3^x4^x6'}
# image set()
# The claim is not satisfied for p=2 for L12457I because of duplicates.
# codomain {'x2^x3^x4^x6'}
# image set()
# The claim is not satisfied for p=1 for L12457J because of duplicates.
# codomain {'x1^x2^x3^x4^x6'}
# image set()
# The claim is not satisfied for p=2 for L12457J because of duplicates.
# codomain {'x2^x3^x4^x6'}
# image set()
# The claim is not satisfied for p=1 for L12457J1 because of duplicates.
# codomain {'x1^x2^x3^x4^x6'}
# image set()
# The claim is not satisfied for p=2 for L12457J1 because of duplicates.
# codomain {'x3^x4^x5^x6'}
# image set()
# The claim is not satisfied for p=1 for L12457L because of duplicates.
# codomain {'x1^x2^x3^x4^x5', 'x1^x2^x3^x4^x6'}
# image set()
# The claim is not satisfied for p=2 for L12457L because of duplicates.
# codomain {'x1^x2^x4^x6', 'x3^x4^x5^x6', 'x1^x2^x3^x5'}
# image {'-x1x2x3x5', 'x1x3x4x5'}
# The claim is not satisfied for p=1 for L12357C because of duplicates.
# codomain set()
# image {'2 x1x2x3x4x6', '2 x1x2x3x5x6'}
# The claim is not satisfied for p=2 for L12357C because of duplicates.
# codomain {'x1^x3^x5^x6', 'x3^x4^x5^x6'}
# image {'x1x2x5x6 - x1x3x4x6'}
# The claim is not satisfied for p=1 for L123457C because of duplicates.
# codomain {'x1^x2^x3^x4^x6'}
# image set()
# The claim is not satisfied for p=2 for L123457C because of duplicates.
# codomain {'x1^x3^x5^x6', 'x3^x4^x5^x6'}
# image set()
# The claim is not satisfied for p=1 for L123457F because of duplicates.
# codomain {'x1^x2^x3^x4^x6'}
# image set()
# The claim is not satisfied for p=2 for L123457F because of duplicates.
# 33

# %% [markdown]
# codomain {'x1^x2^x4^x6', 'x3^x4^x5^x6', 'x2^x3^x5^x6', 'x1^x2^x3^x5'}
# image {'x1x3x4x6', 'x1x3x4x5', 'x1x2x4x6 + x2x3x4x5', '-x1x2x3x5'}
# The claim is satisfied for p=1 for L137D in terms of duplicates.
# codomain {'x1^x2^x3^x4^x5', 'x1^x2^x4^x5^x6', 'x1^x2^x3^x4^x6'}
# image {'-2 x1x3x4x5x6', '2 x1x2x3x4x6', '2 x1x2x3x5x6'}
# The claim is satisfied for p=2 for L137D in terms of duplicates.
# Succes for L137D
#
# codomain {'x1^x3^x5^x6', 'x1^x3^x4^x6', 'x3^x4^x5^x6'}
# image {'1/2 x1x2x3x4', 'x1x2x3x6 + 1/2 x1x3x4x6', '-x1x4x5x6 + x2x3x4x6'}
# The claim is satisfied for p=1 for L1357L in terms of duplicates.
# codomain {'x1^x2^x3^x4^x5'}
# image {'-2 x1x2x3x4x5 - x1x2x4x5x6'}
# The claim is satisfied for p=2 for L1357L in terms of duplicates.
# Succes for L1357L
