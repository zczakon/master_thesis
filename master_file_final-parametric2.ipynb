# %%
#TODO: fix creating base forms for linear combs.
import itertools
import numpy as np
import re
from fractions import Fraction

# %%
#dictionary/algebra definitions

dic17 = {('x1','x2'): {'x7':1}, ('x3','x4'): {'x7':1}, ('x5','x6'): {'x7':1}}
L17.<x1,x2,x3,x4,x5,x6,x7> = LieAlgebra(QQ, dic17)

dic157 = {('x1','x2'): {'x3':1}, ('x1','x3'): {'x7':1}, ('x2','x4'): {'x7':1}, ('x5','x6'): {'x7':1}}
L157.<x1,x2,x3,x4,x5,x6,x7> = LieAlgebra(QQ, dic157)

dic147A = {('x1','x2'): {'x4':1}, ('x1','x3'): {'x5':1}, ('x1','x6'): {'x7':1}, ('x2','x5'): {'x7':1},  
           ('x3','x4'): {'x7':1}}
L147A.<x1,x2,x3,x4,x5,x6,x7> = LieAlgebra(QQ, dic147A)

dic147A1 = {('x1','x2'): {'x4':1}, ('x1','x3'): {'x5':1}, ('x1','x6'): {'x7':1}, ('x2','x4'): {'x7':1},  
           ('x3','x5'): {'x7':1}}
L147A1.<x1,x2,x3,x4,x5,x6,x7> = LieAlgebra(QQ, dic147A1)

dic147B = {('x1','x2'): {'x4':1}, ('x1','x3'): {'x5':1}, ('x1','x4'): {'x7':1}, ('x2','x6'): {'x7':1},  
           ('x3','x5'): {'x7':1}}
L147B.<x1,x2,x3,x4,x5,x6,x7> = LieAlgebra(QQ, dic147B)

dic147D = {('x1','x2'): {'x4':1}, ('x1','x3'): {'x6':-1}, ('x1','x5'): {'x7':1}, ('x1','x6'): {'x7':1},  
           ('x2','x3'): {'x5':1}, ('x2','x6'): {'x7':1}, ('x3','x4'): {'x7':-2}}
L147D.<x1,x2,x3,x4,x5,x6,x7> = LieAlgebra(QQ, dic147D)

def L147E(c):
    dic147E = {('x1','x2'): {'x4':1}, ('x1','x3'): {'x6':-1}, ('x1','x5'): {'x7':-1}, ('x2','x3'): {'x5':1},  
           ('x2','x6'): {'x7':c}, ('x3','x4'): {'x7':(1-c)}}
    L147E.<x1,x2,x3,x4,x5,x6,x7> = LieAlgebra(QQ, dic147E)
    return L147E


def L147E1(c):
    dic147E1 = {('x1','x2'): {'x4':1}, ('x2','x3'): {'x5':1}, ('x1','x3'): {'x6':-1}, ('x1','x6'): {'x7':-c},  
           ('x2','x5'): {'x7':c}, ('x2','x6'): {'x7':2}, ('x3','x4'): {'x7':-2}}
    L147E1.<x1,x2,x3,x4,x5,x6,x7> = LieAlgebra(QQ, dic147E1)
    return L147E1

dic1457B = {('x1','x2'): {'x3':1}, ('x1','x3'): {'x4':1}, ('x1','x4'): {'x7':1}, ('x2','x3'): {'x7':1},  
           ('x5','x6'): {'x7':1}}
L1457B.<x1,x2,x3,x4,x5,x6,x7> = LieAlgebra(QQ, dic1457B)

dic137B = {('x1','x2'): {'x5':1}, ('x1','x5'): {'x7':1}, ('x2','x4'): {'x7':1}, ('x3','x4'): {'x6':1},  
           ('x3','x6'): {'x7':1}}
L137B.<x1,x2,x3,x4,x5,x6,x7> = LieAlgebra(QQ, dic137B)

dic137B1 = {('x1','x3'): {'x5':1}, ('x1','x4'): {'x6':1}, ('x1','x5'): {'x7':1}, ('x2','x3'): {'x6':-1},  
           ('x2','x4'): {'x5':1}, ('x2','x6'): {'x7':1}, ('x3','x4'): {'x7':1}}
L137B1.<x1,x2,x3,x4,x5,x6,x7> = LieAlgebra(QQ, dic137B1)

dic137D = {('x1','x2'): {'x5':1}, ('x1','x4'): {'x6':1}, ('x1','x6'): {'x7':1}, ('x2','x3'): {'x6':1},  
           ('x2','x4'): {'x7':1}, ('x3','x5'): {'x7':-1}}
L137D.<x1,x2,x3,x4,x5,x6,x7> = LieAlgebra(QQ, dic137D)

dic1357A = {('x1','x2'): {'x4':1}, ('x1','x4'): {'x5':1}, ('x1','x5'): {'x7':1}, ('x2','x3'): {'x5':1},  
           ('x2','x6'): {'x7':1}, ('x3','x4'): {'x7':-1}}
L1357A.<x1,x2,x3,x4,x5,x6,x7> = LieAlgebra(QQ, dic1357A)

dic1357C = {('x1','x2'): {'x4':1}, ('x1','x4'): {'x5':1}, ('x1','x5'): {'x7':1}, ('x2','x3'): {'x5':1},  
           ('x2','x4'): {'x7':1}, ('x3','x4'): {'x7':-1}, ('x3','x6'): {'x7':1}}
L1357C.<x1,x2,x3,x4,x5,x6,x7> = LieAlgebra(QQ, dic1357C)

dic1357D = {('x1','x2'): {'x3':1}, ('x2','x3'): {'x5':1}, ('x2','x4'): {'x6':1}, ('x1','x6'): {'x7':1},  
           ('x2','x5'): {'x7':1}, ('x3','x4'): {'x7':1}}
L1357D.<x1,x2,x3,x4,x5,x6,x7> = LieAlgebra(QQ, dic1357D)

dic1357F = {('x1','x2'): {'x3':1}, ('x2','x3'): {'x5':1}, ('x2','x4'): {'x6':1}, ('x1','x3'): {'x7':1},  
           ('x2','x5'): {'x7':1}, ('x4','x6'): {'x7':-1}}
L1357F.<x1,x2,x3,x4,x5,x6,x7> = LieAlgebra(QQ, dic1357F)

dic1357F1 = {('x1','x2'): {'x3':1}, ('x2','x3'): {'x5':1}, ('x2','x4'): {'x6':1}, ('x1','x3'): {'x7':1},  
           ('x2','x5'): {'x7':1}, ('x4','x6'): {'x7':1}}
L1357F1.<x1,x2,x3,x4,x5,x6,x7> = LieAlgebra(QQ, dic1357F1)

dic1357H = {('x1','x2'): {'x3':1}, ('x1','x4'): {'x6':1}, ('x1','x6'): {'x7':1}, ('x2','x3'): {'x5':1},  
           ('x2','x5'): {'x7':1}, ('x2','x6'): {'x7':1}, ('x3','x4'): {'x7':-1}}
L1357H.<x1,x2,x3,x4,x5,x6,x7> = LieAlgebra(QQ, dic1357H)

dic1357J = {('x1','x2'): {'x3':1}, ('x1','x3'): {'x7':1}, ('x1','x4'): {'x6':1}, ('x2','x3'): {'x5':1},  
           ('x2','x5'): {'x7':1}, ('x4','x6'): {'x7':1}}
L1357J.<x1,x2,x3,x4,x5,x6,x7> = LieAlgebra(QQ, dic1357J)

dic1357L = {('x1','x2'): {'x3':1}, ('x1','x3'): {'x5':1}, ('x1','x4'): {'x6':1}, ('x1','x5'): {'x7':1},  
           ('x2','x3'): {'x7':1}, ('x2','x4'): {'x5':1}, ('x2','x6'): {'x7':1/2}, ('x3','x4'): {'x7':1/2}}
L1357L.<x1,x2,x3,x4,x5,x6,x7> = LieAlgebra(QQ, dic1357L)

def L1357M(c):
    dic1357M = {('x1','x2'): {'x3':1}, ('x1','x3'): {'x5':1}, ('x1','x4'): {'x6':1}, ('x1','x5'): {'x7':1},  
           ('x2','x4'): {'x5':1}, ('x2','x6'): {'x7':c}, ('x3','x4'): {'x7':(1-c)}}
    L1357M.<x1,x2,x3,x4,x5,x6,x7> = LieAlgebra(QQ, dic1357M)
    return L1357M

def L1357N(c):
    dic1357N = {('x1','x2'): {'x3':1}, ('x1','x3'): {'x5':1}, ('x1','x4'): {'x6':1}, ('x1','x5'): {'x7':1},  
           ('x2','x3'): {'x7':c}, ('x2','x4'): {'x5':1}, ('x3','x4'): {'x7':1}, ('x4','x6'): {'x7':1}}
    L1357N.<x1,x2,x3,x4,x5,x6,x7> = LieAlgebra(QQ, dic1357N)
    return L1357N

dic1357P = {('x1','x2'): {'x3':1}, ('x1','x3'): {'x5':1}, ('x1','x5'): {'x7':1}, ('x2','x3'): {'x6':1},  
           ('x2','x4'): {'x5':1}, ('x2','x6'): {'x7':1}, ('x3','x4'): {'x7':1}}
L1357P.<x1,x2,x3,x4,x5,x6,x7> = LieAlgebra(QQ, dic1357P)

dic1357P1 = {('x1','x2'): {'x3':1}, ('x1','x3'): {'x5':1}, ('x1','x5'): {'x7':1}, ('x2','x3'): {'x6':1},  
           ('x2','x4'): {'x5':1}, ('x2','x6'): {'x7':-1}, ('x3','x4'): {'x7':1}}
L1357P1.<x1,x2,x3,x4,x5,x6,x7> = LieAlgebra(QQ, dic1357P1)

def L1357QRS1(c):
    dic1357QRS1 = {('x1','x2'): {'x3':1}, ('x1','x3'): {'x5':1}, ('x1','x4'): {'x6':1}, ('x1','x5'): {'x7':1},  
           ('x2','x3'): {'x6':-1}, ('x2','x4'): {'x5':1}, ('x2','x6'): {'x7':c}, ('x3','x4'): {'x7':(1-c)}}
    L1357QRS1.<x1,x2,x3,x4,x5,x6,x7> = LieAlgebra(QQ, dic1357QRS1)
    return L1357QRS1

dic1357R = {('x1','x2'): {'x3':1}, ('x1','x3'): {'x5':1}, ('x1','x6'): {'x7':1}, ('x2','x3'): {'x6':1},  
           ('x2','x4'): {'x6':1}, ('x2','x5'): {'x7':1}, ('x3','x4'): {'x7':1}}
L1357R.<x1,x2,x3,x4,x5,x6,x7> = LieAlgebra(QQ, dic1357R)

def L1357S(c):
    dic1357S = {('x1','x2'): {'x3':1}, ('x1','x3'): {'x5':1}, ('x1','x5'): {'x7':1}, ('x1','x6'): {'x7':1},  
           ('x2','x3'): {'x6':1}, ('x2','x4'): {'x6':1}, ('x2','x5'): {'x7':1}, ('x2','x6'): {'x7':c},
            ('x3','x4'): {'x7':1}}
    L1357S.<x1,x2,x3,x4,x5,x6,x7> = LieAlgebra(QQ, dic1357S)
    return L1357S


dic13457C = {('x1','x2'): {'x3':1}, ('x1','x3'): {'x4':1}, ('x1','x4'): {'x5':1}, ('x1','x6'): {'x7':1},  
           ('x2','x5'): {'x7':1}, ('x3','x4'): {'x7':-1}}
L13457C.<x1,x2,x3,x4,x5,x6,x7> = LieAlgebra(QQ, dic13457C)

dic13457E = {('x1','x2'): {'x3':1}, ('x1','x3'): {'x4':1}, ('x1','x4'): {'x5':1}, ('x1','x6'): {'x7':1},  
           ('x2','x3'): {'x5':1}, ('x2','x5'): {'x7':1}, ('x3','x4'): {'x7':-1}}
L13457E.<x1,x2,x3,x4,x5,x6,x7> = LieAlgebra(QQ, dic13457E)

dic13457G = {('x1','x2'): {'x3':1}, ('x1','x3'): {'x4':1}, ('x1','x4'): {'x5':1}, ('x1','x6'): {'x7':1},  
           ('x2','x3'): {'x6':1}, ('x2','x4'): {'x7':1}, ('x2','x5'): {'x7':1}, ('x3','x4'): {'x7':-1}}
L13457G.<x1,x2,x3,x4,x5,x6,x7> = LieAlgebra(QQ, dic13457G)

dic13457I = {('x1','x2'): {'x3':1}, ('x1','x3'): {'x4':1}, ('x1','x4'): {'x5':1}, ('x1','x5'): {'x7':1},  
           ('x2','x3'): {'x6':1}, ('x2','x5'): {'x7':1}, ('x2','x6'): {'x7':1}, ('x3','x4'): {'x7':-1}}
L13457I.<x1,x2,x3,x4,x5,x6,x7> = LieAlgebra(QQ, dic13457I)

dic12457D = {('x1','x2'): {'x3':1}, ('x1','x3'): {'x4':1}, ('x2','x6'): {'x7':1}, ('x2','x5'): {'x6':1},  
           ('x1','x4'): {'x6':1}, ('x1','x5'): {'x7':1}, ('x3','x4'): {'x7':-1}}
L12457D.<x1,x2,x3,x4,x5,x6,x7> = LieAlgebra(QQ, dic12457D)

dic12457E = {('x1','x2'): {'x3':1}, ('x1','x3'): {'x4':1}, ('x1','x4'): {'x6':1}, ('x1','x6'): {'x7':1},  
           ('x2','x3'): {'x6':1}, ('x2','x4'): {'x7':1}, ('x2','x5'): {'x6':1}, ('x3','x5'): {'x7':1}}
L12457E.<x1,x2,x3,x4,x5,x6,x7> = LieAlgebra(QQ, dic12457E)

dic12457G = {('x1','x2'): {'x3':1}, ('x1','x3'): {'x4':1}, ('x1','x4'): {'x6':1}, ('x1','x5'): {'x7':1},  
           ('x2','x5'): {'x6':1}, ('x2','x6'): {'x7':1}, ('x2','x3'): {'x6':1}, ('x3','x4'): {'x7':-1}}
L12457G.<x1,x2,x3,x4,x5,x6,x7> = LieAlgebra(QQ, dic12457G)

dic12457I = {('x1','x2'): {'x3':1}, ('x1','x3'): {'x4':1}, ('x1','x5'): {'x6':1}, ('x1','x6'): {'x7':1},  
           ('x3','x4'): {'x7':1}, ('x2','x5'): {'x7':1}, ('x2','x3'): {'x5':1}, ('x2','x4'): {'x6':1}}
L12457I.<x1,x2,x3,x4,x5,x6,x7> = LieAlgebra(QQ, dic12457I)

dic12457J = {('x1','x2'): {'x3':1}, ('x1','x3'): {'x4':1}, ('x1','x5'): {'x6':1}, ('x1','x6'): {'x7':1},  
           ('x1','x4'): {'x7':1}, ('x2','x3'): {'x5':1}, ('x2','x4'): {'x6':1}, ('x2','x5'): {'x7':1}, 
             ('x3','x4'): {'x7':1}}
L12457J.<x1,x2,x3,x4,x5,x6,x7> = LieAlgebra(QQ, dic12457J)

dic12457J1 = {('x1','x2'): {'x3':1}, ('x1','x3'): {'x4':1}, ('x1','x5'): {'x6':1}, ('x1','x6'): {'x7':1},  
           ('x1','x4'): {'x7':1}, ('x2','x5'): {'x7':-1}, ('x2','x3'): {'x5':1}, ('x2','x4'): {'x6':1}, 
              ('x3','x4'): {'x7':1}}
L12457J1.<x1,x2,x3,x4,x5,x6,x7> = LieAlgebra(QQ, dic12457J1)

dic12457L = {('x1','x2'): {'x3':1}, ('x1','x3'): {'x4':1}, ('x1','x5'): {'x6':1}, ('x1','x6'): {'x7':1},  
           ('x3','x4'): {'x7':1}, ('x2','x6'): {'x7':1}, ('x2','x3'): {'x5':1}, ('x2','x4'): {'x6':1}, 
              ('x3','x5'): {'x7':-1}}
L12457L.<x1,x2,x3,x4,x5,x6,x7> = LieAlgebra(QQ, dic12457L)

def L12457N(c):
    dic12457N = {('x1','x2'): {'x3':1}, ('x1','x3'): {'x4':1}, ('x1','x5'): {'x6':1}, ('x1','x6'): {'x7':1},  
           ('x1','x4'): {'x7':1}, ('x2','x3'): {'x5':1}, ('x2','x4'): {'x6':1}, ('x2','x5'): {'x7':c}, 
              ('x2','x6'): {'x7':1}, ('x3','x4'): {'x7':1}, ('x3','x5'): {'x7':-1}}
    L12457N.<x1,x2,x3,x4,x5,x6,x7> = LieAlgebra(QQ, dic12457N)
    return L12457N

def L12457N2(c):
    dic12457N2 = {('x1','x2'): {'x3':1}, ('x1','x3'): {'x4':1}, ('x1','x4'): {'x6':-1}, ('x1','x5'): {'x7':1},  
           ('x1','x6'): {'x7':1}, ('x2','x3'): {'x5':1}, ('x2','x4'): {'x7':1}, ('x2','x5'): {('x6','x7'):(-1,c)}, #-x6+cx7 
              ('x3','x5'): {'x7':-1}}
    L12457N2.<x1,x2,x3,x4,x5,x6,x7> = LieAlgebra(QQ, dic12457N2)
    return L12457N2

dic12357C = {('x1','x2'): {'x4':1}, ('x1','x4'): {'x5':1}, ('x1','x5'): {'x6':1}, ('x1','x6'): {'x7':1},  
           ('x2','x3'): {'x5':1}, ('x2','x4'): {'x7':1}, ('x3','x4'): {'x6':-1}, ('x3','x5'): {'x7':-1}}
L12357C.<x1,x2,x3,x4,x5,x6,x7> = LieAlgebra(QQ, dic12357C)

dic123457C = {('x1','x2'): {'x3':1}, ('x1','x3'): {'x4':1}, ('x1','x4'): {'x5':1}, ('x1','x5'): {'x6':1},  
           ('x1','x6'): {'x7':1}, ('x2','x5'): {'x7':1}, ('x3','x4'): {'x7':-1}}
L123457C.<x1,x2,x3,x4,x5,x6,x7> = LieAlgebra(QQ, dic123457C)

dic123457F = {('x1','x2'): {'x3':1}, ('x1','x3'): {'x4':1}, ('x1','x4'): {'x5':1}, ('x1','x5'): {'x6':1},  
           ('x1','x6'): {'x7':1}, ('x2','x3'): {'x6':1}, ('x2','x4'): {'x7':1}, ('x2','x5'): {'x7':1}, 
              ('x3','x4'): {'x7':-1}}
L123457F.<x1,x2,x3,x4,x5,x6,x7> = LieAlgebra(QQ, dic123457F)

def L123457I(c):
    dic12457I = {('x1','x2'): {'x3':1}, ('x1','x3'): {'x4':1}, ('x1','x4'): {'x5':1}, ('x1','x5'): {'x6':1},  
           ('x1','x6'): {'x7':1}, ('x2','x3'): {'x5':1}, ('x3','x4'): {'x7':(1-c)}, ('x2','x5'): {'x7':c}, 
              ('x2','x4'): {'x6':1}}
    L12457I.<x1,x2,x3,x4,x5,x6,x7> = LieAlgebra(QQ, dic12457I)
    return L12457I

# %%
lie_algebra=L123457I(2.29)

cochain = lie_algebra.chevalley_eilenberg_complex(dual=True)
cohomology = cochain.homology(generators=True) 
print(cochain.homology())

generate_cohomology(lie_algebra,4)
# Out:
# {0: Vector space of dimension 1 over Rational Field, 1: Vector space of dimension 2 over Rational Field, 2: Vector space of dimension 3 over Rational Field, 3: Vector space of dimension 4 over Rational Field, 4: Vector space of dimension 4 over Rational Field, 5: Vector space of dimension 3 over Rational Field, 6: Vector space of dimension 2 over Rational Field, 7: Vector space of dimension 1 over Rational Field}
# [[[-1.0, x1, x3, x5, x6], [1.0, x2, x5, x6, x7], [-1.0, x1, x2, x3, x5]], [[-1.0, x3, x4, x5, x6], [1.29, x2, x3, x4, x6]], [[1.0, x1, x4, x6, x7], [-1.0, x2, x3, x4, x6]], [[1.0, x1, x2, x3, x7], [-1.0, x1, x4, x5, x6], [1.0, x2, x3, x6, x7]]]
# ['-1.0 x1^x3^x5^x6 + 1.0 x2^x5^x6^x7 + -1.0 x1^x2^x3^x5',
#  '-1.0 x3^x4^x5^x6 + 1.29 x2^x3^x4^x6',
#  '1.0 x1^x4^x6^x7 + -1.0 x2^x3^x4^x6',
#  '1.0 x1^x2^x3^x7 + -1.0 x1^x4^x5^x6 + 1.0 x2^x3^x6^x7']

# %%
#name getters because SageMath is stupid

algebras_static=[L17, L157, L147A, L147A1, L147B, L147D, L1457B, L137B, L137B1, L137D, L1357A, L1357C, L1357D, L1357F, L1357F1, L1357H, L1357J, L1357L, L1357P, L1357P1, L1357R, L13457C, L13457E, L13457G, L13457I, L12457D, L12457E, L12457G, L12457I, L12457J, L12457J1, L12457L, L12357C, L123457C, L123457F]
dics=[dic17, dic157, dic147A, dic147A1, dic147B, dic147D, dic1457B, dic137B, dic137B1, dic137D, dic1357A, dic1357C, dic1357D, dic1357F, dic1357F1, dic1357H, dic1357J, dic1357L, dic1357P, dic1357P1, dic1357R, dic13457C, dic13457E, dic13457G, dic13457I, dic12457D, dic12457E, dic12457G, dic12457I, dic12457J, dic12457J1, dic12457L, dic12357C, dic123457C, dic123457F]
algebras_dics=[(algebras_static[i],dics[i]) for i in range(35)]

algebra_names=['L17', 'L157', 'L147A', 'L147A1', 'L147B', 'L147D', 'L1457B', 'L137B', 'L137B1', 'L137D', 'L1357A', 'L1357C', 'L1357D', 'L1357F', 'L1357F1', 'L1357H', 'L1357J', 'L1357L', 'L1357P', 'L1357P1', 'L1357R', 'L13457C', 'L13457E', 'L13457G', 'L13457I', 'L12457D', 'L12457E', 'L12457G', 'L12457I', 'L12457J', 'L12457J1', 'L12457L', 'L12357C', 'L123457C', 'L123457F',
              'L147E','L147E1','L1357M','L1357N','L1357QRS1','L1357S','L12457N','L123457I']
dic_names = str(algebra_names).replace('L1','dic1').replace("'","").strip('][').split(', ')
names=[(algebra_names[i],dic_names[i]) for i in range(len(algebra_names))]

algebras=algebras_static+algebras_parametric(2.29)

def get_algebra_name(L):
    name_algebra_dict=dict(zip(algebra_names,algebras))
    for name, algebra in name_algebra_dict.items():
        if algebra == L:
            return name
        
def algebras_parametric(a):
    return [L147E(a),L147E1(a),L1357M(a),L1357N(a),L1357QRS1(a),L1357S(a),L12457N(a),L123457I(a)]

algebras_parametric(2.29)
# Out:
# [Lie algebra on 7 generators (x1, x2, x3, x4, x5, x6, x7) over Rational Field,
#  Lie algebra on 7 generators (x1, x2, x3, x4, x5, x6, x7) over Rational Field,
#  Lie algebra on 7 generators (x1, x2, x3, x4, x5, x6, x7) over Rational Field,
#  Lie algebra on 7 generators (x1, x2, x3, x4, x5, x6, x7) over Rational Field,
#  Lie algebra on 7 generators (x1, x2, x3, x4, x5, x6, x7) over Rational Field,
#  Lie algebra on 7 generators (x1, x2, x3, x4, x5, x6, x7) over Rational Field,
#  Lie algebra on 7 generators (x1, x2, x3, x4, x5, x6, x7) over Rational Field,
#  Lie algebra on 7 generators (x1, x2, x3, x4, x5, x6, x7) over Rational Field]

# %%
#our setting
n=3
U = Manifold(2*n+1, 'U')
X.<x1,x2,x3,x4,x5,x6,x7> = U.chart()
dic=dic17

# %%
#toolkit for displaying cohomology generators 

def ordered_forms(generators: iter, deg: int):
    if not 1 <= deg < len(generators):
        print('degree not allowed')
        pass
    generators = list(set(itertools.combinations(generators, deg)))
    return sorted(generators)


def extract_vector(element):  #of the form Chain(1:(0, 1, 0, 0))
    element = str(element)
    gen = element[9:len(element) - 2]
    gen=gen.split(', ')
    #gen=gen.replace(', ', '').replace('-', '').replace('1/2','1').replace('3/2','1').replace('1/3','1').replace('2/3','1')
    vector = [float(Fraction((gen[i]))) for i in range(len(gen))]
    return vector


def translate_to_forms(homology_gens: list, deg: int, generators: iter):
    """
    return list of lists which are wedge products of generating forms. list(x^y^z, y^z^w,...)
    """
    homology_gens = homology_gens[0]

    generating_forms = []
    for n in range(len(homology_gens)):
        # vector = extract part of a string
        vector = extract_vector(homology_gens[n][1])
        generating_forms.append([])
        for i in range(len(vector)):
            if vector[i] != 0:
                to_append=list(ordered_forms(generators, deg)[i])
                to_append.insert(0,vector[i])
                generating_forms[n].append(to_append)
            elif vector[i] == 1:
                generating_forms[n].append(ordered_forms(generators, deg)[i])
    #print(generating_forms)
    return generating_forms


def cohomology_deg(cohomology: dict, deg: int):
    return [cohomology[key] for key in cohomology.keys() if key == deg]

# def generate_cohomology(lie_algebra, deg):
#     generators = list(lie_algebra.gens())
#     if deg == 0 or deg >= len(generators):
#         print('degree not allowed')
#         return
#     cochain = lie_algebra.chevalley_eilenberg_complex(dual=True)
#     cohomology = cochain.homology(generators=True)
#     cohomologies = [cohomology_deg(cohomology, n) for n in range(len(cohomology.keys()))]
#     list_of_generators= translate_to_forms(cohomologies[deg], deg=deg, generators=generators)

#     generators_readable=[]
#     for i in range(len(list_of_generators)):       
#         generators_readable_i=[]
#         for j in range(len(list_of_generators[i])):
#             li_gen = (list_of_generators[i][j])
#             coeff=str(li_gen[0])#.replace('1.0','') ###if tests crash remove replace
#             form=li_gen[1:]
#             form= str(form).replace(', ', '^').replace('[', '').replace(']', '').replace(',', '')
#             string=' '.join([coeff,form])

#             generators_readable_i.append(string)
#         generators_readable.append(' + '.join(generators_readable_i))
        
#     return generators_readable

# %%
#toolkit for operating between forms and their string representations. 
#linearize is for generalizing functions to linear combinations

def to_form(form_string):
    return linearize(form_string, __to_form__, dic=dic)
    
    
def __to_form__(form_string, dic=dic):
    #works on basis
    if form_string=='0':
        return 0
    form_string=form_string.replace('^','')
    n=len(form_string)/2
    f=U.diff_form(n,'f')
    if n==1:
        i=int(form_string[1])-1
        f[i]=1
    if n>=2:
        vector=np.zeros(n)
        for i in range(n):
            vector[i]=int(form_string[i*2+1])-1
        vector=vector.astype(int)
        exec('f'+str(list(vector))+'=1')       
    return f


def to_string(form):
    if type(form)==str:
        form=simplify(form)
        'already a form string'
        return form
    try:
        if form==0:
            return '0'
    except StopIteration:
        return '0'    
    form_string= str(form.display())
    return simplify(form_string)


def simplify(form_string):
    form_string = form_string.replace('^','').replace('/\\','').replace('d','')
    try:
        return form_string.split(' = ')[1]
    except:
        #if form_string.split('-')[1][0]==' ':
        form_string = form_string.replace('- x','-1 x')
        return form_string

def linearize(form, nform_method, dic=dic):
    form_string=to_string(form) #form_string = '-2 x1 + x2'
    if form_string == '0':
        return 0
    elif is_1_form(form_string):
        if len(form_string)==2:
            return nform_method(form_string, dic)
        else:
            split=form_string.split(' ')
            result=float(split[0])*nform_method(split[1],dic)  
    else:
        split=form_string.split(' ')
        result=0
        for i in range(len(split)):
            if split[i]==0 or split[i]=='+':
                continue
            elif split[i]=='-' and is_constant(split[i+1]):
                split[i+1]=(-1)*float(Fraction(split[i+1]))
                continue
            elif is_constant(split[i]):
                split[i]=float(Fraction(split[i]))
                result += split[i]*nform_method(split[i+1],dic)
                split[i+1]=0
            else:
                result+= nform_method(split[i],dic)
    try:
        trial=result.display()
        return result
    except AttributeError:
        return 0

    
def is_constant(form_string):
    form_string=str(form_string)
    if 'x' in form_string:
        return False
    else:
        return True
    
def is_1_form(form_string):
    if form_string.count('x')==1:
        return True
    else:
        return False

# %%
#methods for checking different Lefachetz theorem statements 


def domainify(n):
    domain=set(generate_cohomology(L,n))
    while '0' in domain:
        domain.remove('0')
    return domain

def check_lefschetz_theorem(L,dic=dic):
    flag=0
    for p in range(0,3):
        domain=domainify(3-p)
        codomain=domainify(3+p+1)
        image=set([to_string(lefschetz(to_form(gen),p,dic)) for gen in domain])
        print('domain',domain)
        print('codomain',codomain)
        print('image',image)
        if '0' in image:
            print('The claim is not satisfied for p='+str(p)+' for '+get_algebra_name(L)+' because of 0 in the image.')
            return False
        if len(image)!=len(codomain):
            print('The claim is not satisfied for p='+str(p)+' for '+get_algebra_name(L)+' because of duplicates.')
            return False
    if flag==1:
        return False
    else:
        print('Success for',get_algebra_name(L))
        return True

def check_lefschetz_theoremB(L,dic=dic):
    flag=0
    for p in range(1,3): 
        domain=[gen for gen in domainify(3-p) if 'x7' not in gen] 
        codomain=[gen for gen in domainify(3+p) if 'x7' not in gen]
        image=set([to_string(lefschetzB(to_form(gen),p,dic)) for gen in domain])
        
        print('domain',domain)
        print('codomain',codomain)
        print('image',image)
        if '0' in image:
            print('The claim is not satisfied for p='+str(p)+' for '+get_algebra_name(L)+' because of 0 in the image.')
            flag = 1 
        elif len(image)!=len(codomain):
            print('The claim is not satisfied for p='+str(p)+' for '+get_algebra_name(L)+' because of duplicates.')
            flag = 1
        else:
            print('for p=',p,'for',get_algebra_name(L),'it is fine')
            continue
    if flag ==1:
        return False
    else:
        print('Success for',get_algebra_name(L))
        return True

def lefschetz(form, p, dic=dic):
    contact=U.diff_form(1,'n')
    contact[6]=1
    #print('d(contact) ',str(d(contact,dic).display()))
    return __wedge__(__wedge__(contact,pow(d(contact,dic),p)),proj(form,dic))
                        
def lefschetzB(form, p, dic=dic):
    contact=U.diff_form(1,'n')
    contact[6]=1
    return __wedge__(pow(d(contact,dic),p),proj(form,dic))

# %%
#basic operators on differential forms 

def __proj__(form_string,dic=dic):
    if d(form_string,dic)==0 and d_star(form_string,dic)==0:
        return to_form(form_string)
    else:
        return 0
    
def proj(form,dic=dic):
    return linearize(form,__proj__,dic=dic)
    
def pow(form, p):
    result=form
    if p==0:
        return 1
    elif p==1 or form == 0:
        return result
    else:
        for i in range(p-1):
            result= __wedge__(result,form)
    return result

def __d__(form_string, dic):
    #TODO the one with two gens in structure constants
    d=U.diff_form(2,'d')
    for structure_const in dic.values():
        if list(structure_const.keys())[0]==form_string:
            keys=[]
            for key, value in dic.items():
                if value == structure_const:
                    i=int(key[0][1])-1
                    j=int(key[1][1])-1
                    d[i,j]=list(structure_const.values())[0]
    try:
        trial=d.display()
        return d
    except ValueError:
        return 0

def d_of_nform(form_string,dic=dic):
    if form_string==0:
        return 0
    elif is_1_form(form_string):
        return __d__(form_string,dic)
    else:
        form1_string=form_string[:2]
        form2_string=form_string[2:]
        return __wedge__(d(to_form(form1_string),dic),to_form(form2_string)) - __wedge__(to_form(form1_string),d(to_form(form2_string),dic))

def d(form,dic=dic):
    return linearize(form, d_of_nform, dic)
            
def __wedge__(form1, form2):
    if form1==0 or form2==0:
        return 0
    elif form2 ==1:
        return form1
    elif form1==1:
        return form2
    else:
        return form1.wedge(form2)
    
def __star__(form_string, dic=dic):
    #works for nforms from basis
    if form_string=='0':
        return 0
    return psi_base(phi_inv_base(to_form(form_string)))

def star(form, dic=dic):
    return linearize(form, __star__, dic=dic)

def d_star(form, dic=dic):
    form_string=to_string(form)                  
    dim=len(form_string)/2
    return (-1)**dim*star(d(star(form),dic))

# %% [markdown]
# Implementing the star operator for contact manifold:
# $$\phi:X^*(M) \to \Omega^*(M)$$
# $$\phi^{-1}:\Omega^*(M)\to X^*(M)$$
# $$\psi:X^*(M) \to \Omega^{2n-*}(M) $$
# $$\star :\Omega^*(M) \to X^*(M) \to \Omega^{2n-*}(M), \; \star \beta =\psi \circ \phi^{-1}(\beta)$$

# %%
def __phi__(v, dic=dic):
    contact=to_form('x7')
    deta=d(contact,dic)
    return v.interior_product(deta)

def create_phi_map_dict(dic=dic):
    #TODO fix the -1's
    phi_map={}
    for i in range(7):
        t=np.zeros(7)
        t[i]=1
        v=U.vector_field('v')
        v[:]=tuple(t)
        image=to_string(__phi__(v, dic))        
        if '-' in image:
            t[i]=-1*t[i]
            phi_map[tuple(t)]=image.replace('-','')
        else:
            phi_map[tuple(t)]=image 
    return phi_map

def invert_map(map_dictionary):
    return {v: k for k, v in map_dictionary.items()}

# %%
def split_to_1forms(base_form):
    base_form=to_string(base_form)
    return [base_form[2*i:(2*i+2)] for i in range(len(base_form)/2)]

def __phi_inv__(form_string, dic=dic):
    phi_map=create_phi_map_dict(dic)
    inv_phi_map = invert_map(phi_map)
    #I have to map 'x7' to sth, but it's not used in B.
    inv_phi_map['x7'] = inv_phi_map['0']
    inv_phi_map.pop('0', None)
    return inv_phi_map[form_string]

def phi_inv_base(form):
    #works on base forms
    split=split_to_1forms(form)
    return [__phi_inv__(one_form) for one_form in split]

def compute_volume_form(dic=dic):
    #dn^3
    contact=to_form('x7')
    deta=d(contact,dic)
    return deta.wedge(deta).wedge(deta)

def to_vector_field(vf_tuple):
    v=U.vector_field('v')
    v[:]=vf_tuple
    return v

def psi_base(list_vf, dic=dic):
    #returns a form
    #volume form is \omega=d\eta
    list_vf=list(map(to_vector_field, list_vf))
    volume_form=compute_volume_form(dic)
    result=list_vf[::-1][0].interior_product(volume_form)
    n=len(list_vf)
    if n==1:
        return result
    for i in range(1,len(list_vf)):
        result=list_vf[::-1][0].interior_product(result)
    return result

# %%
#test suite

class TestNotebook:
    def _assertEqual_(self,a, b):
        res = a == b
        try:
            if type(res) is bool:
                if not res:
                    print('Assert not okay. "{}" is not "{}"'.format(a, b))
                    return
            else:
                if not res.all():
                    print('Assert not okay. "{}" is not "{}"'.format(a, b))
                    return
            print('Assert okay.')
        except:
            print('Test failed for unknown reason.')
        
    def test_d(self):
        self._assertEqual_(d(to_form('0'),dic17),0)
        self._assertEqual_(d(to_form('x2'),dic17),0)
        self._assertEqual_(d(to_form('x7'),dic17),to_form('x1^x2 + x3^x4 + x5^x6'))
        self._assertEqual_(d(to_form('x7 + x2'),dic17),to_form('x1^x2 + x3^x4 + x5^x6'))
        self._assertEqual_(d(to_form('2 x7 + x2'),dic17),to_form('2 x1^x2 + 2 x3^x4 + 2 x5^x6'))
        self._assertEqual_(d(to_form('1/2 x7 + x2'),dic17),to_form('0.5 x1^x2 + 0.5 x3^x4 + 0.5 x5^x6'))
        self._assertEqual_(d(to_form('1/2 x7 + 3/2 x2'),dic17),to_form('0.5 x1^x2 + 0.5 x3^x4 + 0.5 x5^x6'))
        self._assertEqual_(d(to_form('1/2 x7 + 0.5 x7'),dic17),to_form('x1^x2 + x3^x4 + x5^x6'))
        self._assertEqual_(d(to_form('x3'),dic157),to_form('x1^x2'))
    
    def test_to_string(self):
        f=U.diff_form(1,'f')
        g=U.diff_form(1,'g')
        self._assertEqual_(to_string(f),'0')
        f[0]=1
        g[1]=1
        self._assertEqual_(to_string(f),'x1')
        self._assertEqual_(to_string(2*f),'2 x1')
        self._assertEqual_(to_string(f+g+0),'x1 + x2')
        self._assertEqual_(to_string(2*f-g),'2 x1 -1 x2')
        
    def test_to_form(self):
        #test if inverse with to_string
        #test minuses
        self._assertEqual_(to_form('0'),0)
        self._assertEqual_(str(to_form(to_string(to_form('2 x1 - x2'))).display()),'2.0 dx1 - 1.0 dx2')
        
    def test_star(self):
        self._assertEqual_(star(to_form('x3'), dic157), to_form('6.0 dx1/\dx2/\dx3/\dx5/\dx6'))
        self._assertEqual_(star(to_form('x5'), dic157), to_form('6.0 dx1/\dx2/\dx3/\dx4/\dx5'))
        self._assertEqual_(star(to_form('x3'),dic157)+star(to_form('x5'),dic157),
                          star(to_form('x3 + x5'),dic157))
        self._assertEqual_(star(to_form('x3'),dic157)-star(to_form('x5'),dic157),
                          star(to_form('x3 - x5'),dic157))
        pass
    
    def test_d_star(self):
        pass

    def test_proj(self):
        #nonharmonic
        self._assertEqual_(proj(to_form('x3'),dic157),0)
        #harmonic
        self._assertEqual_(proj(to_form('x5'),dic157),to_form('x5'))
        self._assertEqual_(proj(to_form('x3 + x5'),dic157),to_form('x5'))
        pass


tn=TestNotebook()

for callable in TestNotebook.__dict__.values():    
    name = getattr(callable, '__name__', '_')
    if not name.startswith('_'):
        print(name,'results:')
        try:
            callable(tn)
        except TypeError:
            pass
# Out:
# <>:48: DeprecationWarning: invalid escape sequence \d
# <>:49: DeprecationWarning: invalid escape sequence \d
# <>:48: DeprecationWarning: invalid escape sequence \d
# <>:49: DeprecationWarning: invalid escape sequence \d
# <>:48: DeprecationWarning: invalid escape sequence \d
# <>:49: DeprecationWarning: invalid escape sequence \d
# <ipython-input-55-0c0f4d65e0c6>:48: DeprecationWarning: invalid escape sequence \d
#   self._assertEqual_(star(to_form('x3'), dic157), to_form('6.0 dx1/\dx2/\dx3/\dx5/\dx6'))
# <ipython-input-55-0c0f4d65e0c6>:49: DeprecationWarning: invalid escape sequence \d
#   self._assertEqual_(star(to_form('x5'), dic157), to_form('6.0 dx1/\dx2/\dx3/\dx4/\dx5'))
# test_d results:
# Assert okay.
# Assert okay.
# Assert okay.
# Assert okay.
# Assert okay.
# Assert okay.
# Assert okay.
# Assert okay.
# Assert okay.
# test_to_string results:
# Assert okay.
# Assert okay.
# Assert okay.
# Assert okay.
# Assert okay.
# test_to_form results:
# Assert okay.
# Assert okay.
# ...

# %%
not_okayB=[]
i=1
for L,dic in algebras_dics:
    print(i)
    i+=1
    if check_lefschetz_theoremB(L,dic)==False:
        not_okayB.append(L)
len(not_okayB)
# Out:
# 1
# [[[1.0, x1, x4]], [[1.0, x4, x7]], [[1.0, x2, x7]], [[1.0, x6, x7]], [[1.0, x1, x6]], [[1.0, x1, x2]], [[1.0, x3, x4]], [[1.0, x4, x5]], [[1.0, x2, x4]], [[1.0, x2, x3]], [[1.0, x3, x5]], [[1.0, x2, x6]], [[1.0, x4, x6]], [[1.0, x1, x3]]]
# [[[1.0, x1, x2, x4, x6]], [[-1.0, x1, x2, x5, x7], [1.0, x2, x4, x5, x7]], [[1.0, x1, x3, x5, x6]], [[1.0, x1, x3, x4, x7]], [[-1.0, x3, x4, x5, x6], [1.0, x2, x3, x5, x6]], [[-1.0, x1, x3, x6, x7], [1.0, x1, x5, x6, x7]], [[1.0, x1, x4, x6, x7], [-1.0, x4, x5, x6, x7]], [[-1.0, x1, x3, x4, x5], [1.0, x3, x5, x6, x7]], [[1.0, x2, x5, x6, x7]], [[1.0, x1, x2, x3, x7]], [[-1.0, x1, x2, x4, x5], [1.0, x1, x2, x3, x6]], [[1.0, x1, x4, x5, x6]], [[1.0, x2, x3, x5, x7]], [[-1.0, x1, x4, x5, x7]]]
# domain ['1.0 x1^x2', '1.0 x4^x6', '1.0 x3^x5', '1.0 x2^x4', '1.0 x4^x5', '1.0 x2^x6', '1.0 x1^x4', '1.0 x2^x3', '1.0 x1^x3', '1.0 x1^x6', '1.0 x3^x4']
# ...

# %%
generate_cohomology_listed(L123457I(2.29),4)
generate_cohomology_listed(L157,4)
generate_base_forms(L123457I(2.29),4)
# Out:
# ['-1.0 x1^x3^x5^x6 + -1.0 x1^x2^x3^x5',
#  '-1.0 x3^x4^x5^x6 + 1.29 x2^x3^x4^x6',
#  '-1.0 x2^x3^x4^x6',
#  '-1.0 x1^x4^x5^x6']

# %%
def generate_cohomology(lie_algebra, deg):
    list_of_generators=generate_cohomology_listed(lie_algebra, deg)
    return display(list_of_generators)
    
def display(list_of_generators):
    generators_readable=[]
    for i in range(len(list_of_generators)):       
        generators_readable_i=[]
        for j in range(len(list_of_generators[i])):
            li_gen = (list_of_generators[i][j])
            coeff=str(li_gen[0])#.replace('1.0','') ###if tests crash remove replace
            form=li_gen[1:]
            form= str(form).replace(', ', '^').replace('[', '').replace(']', '').replace(',', '')
            string=' '.join([coeff,form])

            generators_readable_i.append(string)
        generators_readable.append(' + '.join(generators_readable_i))
    #generators_readable=[gen for gen in generators_readable if gen != '0']   
    return generators_readable


def generate_cohomology_listed(lie_algebra, deg):
    generators = list(lie_algebra.gens())
    if deg == 0 or deg >= len(generators):
        print('degree not allowed')
        return
    cochain = lie_algebra.chevalley_eilenberg_complex(dual=True)
    cohomology = cochain.homology(generators=True)
    cohomologies = [cohomology_deg(cohomology, n) for n in range(len(cohomology.keys()))]
    list_of_generators= translate_to_forms(cohomologies[deg], deg=deg, generators=generators)
    return list_of_generators

def generate_base_forms(algebra, deg):
    list_of_generators=generate_cohomology_listed(algebra,deg) #list of lists
    for i in range(len(list_of_generators)):
        to_delete=[]
        for j in range(len(list_of_generators[i])):
            for k in range(len(list_of_generators[i][j])):
                if 'x7' == str(list_of_generators[i][j][k]):
                    to_delete.append(list_of_generators[i][j])
        list_of_generators[i]=[item for item in list_of_generators[i] if item not in to_delete]
    list_of_generators=[item for item in list_of_generators if item != []] 
    
    return remove_zeros(remove_duplicates(display(list_of_generators)))

def remove_duplicates(mylist):
    return list(dict.fromkeys(mylist))

def remove_zeros(mylist):
    return [elem for elem in mylist if elem != '0']

# %%
#preliminary test on dimensions

def is_isomorphism_possible(L):
    count=0
    for p in range(1,3):
        if len(generate_base_forms(L,n-p))!= len(generate_base_forms(L,n+p)):
            print('Isomorphism not possible for degrees',n-p,',',n+p,'for algebra',str(get_algebra_name(L)))
            count+=1
    return count

count=0
okay_static=[]
for i in range(len(algebras_static)):
    try:
        fails=is_isomorphism_possible(algebras_static[i])
        count+=fails
        if fails<2:
            okay_static.append(algebras_static[i])
    except ValueError:
        print('Found ValueError for algebra',str(names[i]))
print(count)


    

# def is_isomorphism_possible(L):
#     for p in range(0,n):
#         if len(generate_cohomology(L,n-p))!= len(generate_cohomology(L,n+p+1)):
#             print('Isomorphism not possible for degrees',n-p,',',n+p+1,'for algebra',str(algebras_static[L]))
#     pass

# for i in range(len(algebras_static)):
#     try:
#         is_isomorphism_possible(algebras_static[i])
#     except ValueError:
#         print('Found ValueError for algebra',str(names[i]))
# Out:
# Isomorphism not possible for degrees 2 , 4 for algebra L17
# Isomorphism not possible for degrees 1 , 5 for algebra L17
# Isomorphism not possible for degrees 2 , 4 for algebra L157
# Isomorphism not possible for degrees 1 , 5 for algebra L157
# Isomorphism not possible for degrees 2 , 4 for algebra L147A
# Isomorphism not possible for degrees 1 , 5 for algebra L147A
# Isomorphism not possible for degrees 2 , 4 for algebra L147A1
# Isomorphism not possible for degrees 1 , 5 for algebra L147A1
# Isomorphism not possible for degrees 2 , 4 for algebra L147B
# Isomorphism not possible for degrees 1 , 5 for algebra L147B
# Isomorphism not possible for degrees 1 , 5 for algebra L1457B
# Isomorphism not possible for degrees 2 , 4 for algebra L137B
# Isomorphism not possible for degrees 1 , 5 for algebra L137B
# Isomorphism not possible for degrees 2 , 4 for algebra L137B1
# Isomorphism not possible for degrees 1 , 5 for algebra L137B1
# ...

# %%
count=0
okay_param=[]
for algebra in algebras_parametric(2.29):
    fails=is_isomorphism_possible(algebra)
    count+=fails
    if fails<2:
        okay_param.append(algebra)

print(count)
# Out:
# Isomorphism not possible for degrees 1 , 5 for algebra L1357M
# Isomorphism not possible for degrees 2 , 4 for algebra L1357N
# Isomorphism not possible for degrees 1 , 5 for algebra L1357N
# Isomorphism not possible for degrees 2 , 4 for algebra L1357QRS1
# Isomorphism not possible for degrees 1 , 5 for algebra L1357QRS1
# Isomorphism not possible for degrees 2 , 4 for algebra L1357S
# Isomorphism not possible for degrees 1 , 5 for algebra L1357S
# Isomorphism not possible for degrees 2 , 4 for algebra L12457N
# Isomorphism not possible for degrees 2 , 4 for algebra L123457I
# Isomorphism not possible for degrees 1 , 5 for algebra L123457I
# 10

# %%
okay=okay_static+okay_param
[get_algebra_name(algebra) for algebra in okay]
# Out:
# ['L147D',
#  'L1457B',
#  'L1357A',
#  'L1357C',
#  'L1357F',
#  'L1357F1',
#  'L1357J',
#  'L1357R',
#  'L13457G',
#  'L13457I',
#  'L12457D',
#  'L12457E',
#  'L12457G',
#  'L12457L',
#  'L12357C',
#  'L147E',
#  'L147E1',
#  'L1357M',
#  'L12457N']

# %%
def check_theorem(L,dic=dic):
    flag=0
    satisfied={}
    for p in range(1,3): 
        print('Algebra:',get_algebra_name(L),', p=',p)
        domain=generate_base_forms(L,3-p)
        codomain=generate_base_forms(L,3+p)
        image=remove_zeros(remove_duplicates([to_string(lefschetzB(to_form(gen),p,dic)) for gen in domain]))
        
        print('domain',domain,',',len(domain))
        print('codomain',codomain,',',len(codomain))
        print('image',image,',',len(image))
        if len(image)!=len(codomain):
            satisfied[get_algebra_name(L)]=p
#         if '0' in image:
#             print('The claim is not satisfied for p='+str(p)+' for '+get_algebra_name(L)+' because of 0 in the image.')
#             flag = 1 
#         elif len(image)!=len(codomain):
#             print('The claim is not satisfied for p='+str(p)+' for '+get_algebra_name(L)+' because of duplicates.')
#             flag = 1
#         else:
#             print('for p=',p,'for',get_algebra_name(L),'it is fine')
#             continue
#     if flag ==1:
#         return False
#     else:
#         print('Success for',get_algebra_name(L))
#         return True
    return satisfied

satisfied={}
for L in okay:
    satisfied = {**satisfied,**check_theorem(L)}
# Out:
# Algebra: L147D , p= 1
# domain ['1.0 x1^x2', '1.0 x3^x4', '1.0 x4^x5 + -1.0 x2^x4', '1.0 x2^x3', '1.0 x3^x5'] , 5
# codomain ['-1.0 x1^x2^x4^x6', '1.0 x1^x3^x5^x6', '-1.0 x3^x4^x5^x6 + 2.0 x1^x2^x3^x5', '-1.0 x1^x2^x3^x5', '1.0 x1^x2^x4^x5'] , 5
# image ['-2 x1x2x3x4', '-1.0 x1x2x4x5 - 1.0 x1x2x4x6', 'x1x2x3x5 + x1x2x3x6', 'x1x3x5x6 + x2x3x5x6'] , 4
# Algebra: L147D , p= 2
# domain ['1.0 x4', '1.0 x3', '1.0 x2'] , 3
# codomain ['-1.0 x1^x2^x3^x5^x6', '1.0 x1^x2^x3^x4^x5', '1.0 x1^x2^x3^x4^x6'] , 3
# image ['-2 x1x2x3x5x6', '4 x1x2x3x4x5 + 4 x1x2x3x4x6'] , 2
# Algebra: L1457B , p= 1
# domain ['1.0 x1^x6', '1.0 x3^x4', '1.0 x4^x5', '1.0 x1^x3'] , 4
# codomain ['1.0 x1^x3^x5^x6', '1.0 x1^x2^x3^x5', '1.0 x1^x3^x4^x6', '1.0 x3^x4^x5^x6'] , 4
# image ['-2 x1x3x4x6', '-x1x2x3x6'] , 2
# Algebra: L1457B , p= 2
# domain ['1.0 x4', '1.0 x3', '1.0 x1'] , 3
# codomain ['1.0 x1^x2^x3^x4^x6', '-1.0 x1^x2^x3^x4^x5'] , 2
# image ['-2 x1x2x3x5x6', '-4 x1x2x3x4x6'] , 2
# Algebra: L1357A , p= 1
# ...

# %%
satisfied
# Out:
# {'L147D': 2,
#  'L1457B': 1,
#  'L1357A': 2,
#  'L1357C': 2,
#  'L1357F': 2,
#  'L1357F1': 2,
#  'L1357J': 2,
#  'L1357R': 1,
#  'L13457G': 2,
#  'L13457I': 2,
#  'L12457D': 2,
#  'L12457E': 2,
#  'L12457G': 2,
#  'L12457L': 2,
#  'L12357C': 2,
#  'L147E': 2,
#  'L147E1': 2,
#  'L1357M': 1,
#  'L12457N': 2}
